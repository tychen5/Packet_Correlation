# %%
import ssdeep
import pickle,os,sys,gc
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
from tqdm import tqdm
from collections import Counter
import multiprocessing as mp
from multiprocessing import Process, Manager, Pool
import time
from itertools import chain
import math
from operator import itemgetter
from collections import Counter

# %%
#  import sys,os
print(sys.executable)
print(sys.version)
print(sys.version_info)
import findspark
os.environ['PYSPARK_PYTHON'] = '/usr/bin/python3' #'/home/antslab/anaconda3/bin/python'
findspark.init()
import pyspark
# from pyspark import SparkContext
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
import pandas as pd
import numpy as np
from tqdm import tqdm
from pyspark.sql import Row, SQLContext, SparkSession, window
from pyspark import SparkConf, SparkContext
# Import data types
from pyspark.sql.types import *
import  pyspark.sql.functions as F
conf = SparkConf()
conf.set("spark.local.dir", "/mnt/ssd240g/data/Leo_Spark_Home/tmp")
conf.set("spark.executor.cores","12")
conf.set("spark.driver.memory","75g")
conf.set("spark.executor.memory", "85g")
conf.set("spark.memory.offHeap.enabled","true")
conf.set("spark.memory.offHeap.size","75g")
conf.set("spark.driver.extraJavaOptions","-Xss15000m")
conf.set("spark.driver.extraJavaOptions","-Xms70g")
# conf.set("spark.memory.storageFraction","0.2")
# conf.set("spark.driver.maxResultSize","0")
conf.set("spark.sql.execution.arrow.pyspark.enabled", "true")
conf.set("spark.sql.execution.arrow.enabled", "true")
conf.set("spark.kubernetes.pyspark.pythonVersion","3")
conf.set("spark.sql.shuffle.partitions",95000)
conf.set("spark.driver.maxResultSize", "150g")

# spark = SparkSession.builder.appName("pcap_analyzer").config(conf=conf).getOrCreate() #pcap_analyzer pcapAnalyzer
spark = SparkSession.builder.master("local").appName("Test_spark").config(conf=conf).getOrCreate()
spark.conf.set("spark.sql.execution.arrow.enabled", True)
spark.conf.set("spark.sql.debug.maxToStringFields", 100000)
spark.conf.set("spark.sql.hive.filesourcePartitionFileCacheSize",90*1024*1024*1024)

import databricks.koalas as ks
ks.options.display.max_rows = 20
ks.set_option('compute.max_rows', None)
# ks.set_option('compute.ops_on_diff_frames', True)
ks.set_option('compute.default_index_type', 'distributed')
print(ks.__version__)
spark.version
# Out:
# /home/antslab/anaconda3/bin/python
# 3.7.7 (default, Mar 26 2020, 15:48:22)
# [GCC 7.3.0]
# sys.version_info(major=3, minor=7, micro=7, releaselevel='final', serial=0)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-3-dd67d0ca373b> in <module>
#      36
#      37 # spark = SparkSession.builder.appName("pcap_analyzer").config(conf=conf).getOrCreate() #pcap_analyzer pcapAnalyzer
# ---> 38 spark = SparkSession.builder.master("local").appName("Test_spark").config(conf=conf).getOrCreate()
#      39 spark.conf.set("spark.sql.execution.arrow.enabled", True)
#      40 spark.conf.set("spark.sql.debug.maxToStringFields", 100000)
#
# /opt/spark/python/pyspark/sql/session.py in getOrCreate(self)
#     181                             sparkConf.set(key, value)
#     182                         # This SparkContext may be an existing one.
# --> 183                         sc = SparkContext.getOrCreate(sparkConf)
#     184                     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     185                     # by all sessions.
#
# /opt/spark/python/pyspark/context.py in getOrCreate(cls, conf)
#     368         with SparkContext._lock:
#     369             if SparkContext._active_spark_context is None:
# --> 370                 SparkContext(conf=conf or SparkConf())
#     371             return SparkContext._active_spark_context
#     372
#
# /opt/spark/python/pyspark/context.py in __init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls)
#     125                 " is not allowed as it is a security risk.")
#     126
# --> 127         SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     128         try:
#     129             self._do_init(master, appName, sparkHome, pyFiles, environment, batchSize, serializer,
#
# /opt/spark/python/pyspark/context.py in _ensure_initialized(cls, instance, gateway, conf)
#     317         with SparkContext._lock:
#     318             if not SparkContext._gateway:
# --> 319                 SparkContext._gateway = gateway or launch_gateway(conf)
#     320                 SparkContext._jvm = SparkContext._gateway.jvm
#     321
#
# /opt/spark/python/pyspark/java_gateway.py in launch_gateway(conf, popen_kwargs)
#     103
#     104             if not os.path.isfile(conn_info_file):
# --> 105                 raise Exception("Java gateway process exited before sending its port number")
#     106
#     107             with open(conn_info_file, "rb") as info:
#
# Exception: Java gateway process exited before sending its port number

# %%
in_file = "/home/antslab/123data_hdd4t/pcap_process/pcap_spark/2020_01_09/中華電信/parquet/2020_01_09_session_v7-2_hashpayload_time_size.parquet"
pickle_dir = '/home/antslab/123_antslab/spark_data/pcap_inter/2020_01_09/中華電信/case_pickles/'
df = pd.read_parquet(in_file)
print(df.columns)
df = df[['session_time','session_time_list','session_duration','session_tt_packet', 'session_i_tt_packet', 'session_o_tt_packet',
             'session_tt_frame_length', 'session_i_tt_frame_length','session_o_tt_frame_length','udp_tt_length', 'udp_i_tt_length',
             'udp_o_tt_length', 'udp_i_avg_length', 'udp_o_avg_length','icmp_i_avg_length', 'icmp_o_avg_length',
             'icmp_tt_original_datagram_length', 'icmp_i_tt_datagram_length','icmp_o_tt_datagram_length', 'icmp_i_avg_datagram_length',
             'icmp_o_avg_datagram_length','tcp_tt_payload_length', 'tcp_i_tt_payload_length','tcp_o_tt_payload_length', 'tcp_i_avg_payload_length',
             'tcp_o_avg_payload_length','ip_src', 'ip_dst','tcp_srcport', 'tcp_dstport', 'udp_srcport', 'udp_dstport', 'country',
             'city', 'subdivisions','domain','isp','frame_i_common_protocols','frame_o_common_protocols', 'frame_i_max_protocols','frame_o_max_protocols', 'tcp_i_payload_list', 'tcp_o_payload_list'        
            ]]
# df['tcp_payload_avg'] = df.tcp_payload_size/df.session_packets
# df['udp_payload_size'] = df.udp_length_sum - (df.session_packets*8)
# df['udp_payload_avg'] = df.udp_payload_size/df.session_packets
# df['icmp_payload_avg'] = df.icmp_length_original_datagram_sum/df.session_packets

 #50461592 
gc.collect()
df
# Out:
# Index(['session_time', 'session_time_list', 'session_duration',
#        'session_tt_packet', 'session_i_tt_packet', 'session_o_tt_packet',
#        'session_tt_frame_length', 'session_i_tt_frame_length',
#        'session_o_tt_frame_length', 'udp_tt_length', 'udp_i_tt_length',
#        'udp_o_tt_length', 'udp_i_avg_length', 'udp_o_avg_length',
#        'icmp_tt_length', 'icmp_i_tt_length', 'icmp_o_tt_length',
#        'icmp_i_avg_length', 'icmp_o_avg_length',
#        'icmp_tt_original_datagram_length', 'icmp_i_tt_datagram_length',
#        'icmp_o_tt_datagram_length', 'icmp_i_avg_datagram_length',
#        'icmp_o_avg_datagram_length', 'tcp_hdr_len_sum',
#        'tcp_tt_payload_length', 'tcp_i_tt_payload_length',
#        'tcp_o_tt_payload_length', 'tcp_i_avg_payload_length',
#        'tcp_o_avg_payload_length', 'ip_avg_ttl', 'ip_max_ttl',
#        'tcp_avg_window', 'tcp_max_window', 'ip_src', 'ip_dst', 'ip_proto',
#        'tcp_srcport', 'tcp_dstport', 'udp_srcport', 'udp_dstport', 'country',
#        'city', 'subdivisions', 'latitude', 'longitude', 'domain', 'isp',
#        'network', 'tcp_flags_i_tt_ack', 'tcp_flags_o_tt_ack',
#        'tcp_flags_i_tt_fin', 'tcp_flags_o_tt_fin', 'tcp_flags_i_tt_push',
#        'tcp_flags_o_tt_push', 'tcp_flags_i_tt_reset', 'tcp_flags_o_tt_reset',
#        'tcp_flags_i_tt_syn', 'tcp_flags_o_tt_syn', 'frame_i_common_protocols',
#        'frame_o_common_protocols', 'frame_i_max_protocols',
#        'frame_o_max_protocols', 'tcp_i_payload_list', 'tcp_o_payload_list'],
#       dtype='object')
#           session_time                                  session_time_list  \
# 0         1.578537e+09                                [1578536536.304474]
# 1         1.578565e+09  [1578564803.525677, 1578564806.728999, 1578564...
# 2         1.578555e+09  [1578554510.42924, 1578554510.42951, 157855451...
# 3         1.578545e+09  [1578545262.456555, 1578545262.456789, 1578545...
# 4         1.578542e+09  [1578541704.028706, 1578541704.029002, 1578541...
# ...                ...                                                ...
# 39691337  1.578572e+09  [1578571782.696612, 1578571782.696941, 1578571...
# 39691338  1.578574e+09             [1578574356.012381, 1578574356.012622]
# 39691339  1.578553e+09             [1578552523.232354, 1578552523.232535]
# 39691340  1.578523e+09             [1578522598.041415, 1578522598.041647]
# 39691341  1.578507e+09             [1578507127.065189, 1578507127.065443]
#
#           session_duration  session_tt_packet  session_i_tt_packet  \
# 0                 0.000000                  1                    1
# 1                10.781249                 21                   10
# 2                16.405455                 35                   12
# 3                 0.597846                  4                    2
# 4                 0.616350                  4                    2
# ...                    ...                ...                  ...
# 39691337          1.367122                 14                    7
# 39691338          0.000241                  2                    1
# 39691339          0.000181                  2                    1
# 39691340          0.000232                  2                    1
# 39691341          0.000254                  2                    1
#
#           session_o_tt_packet  session_tt_frame_length  \
# 0                           0                       66
# 1                          11                     2021
# 2                          23                     3498
# 3                           2                      252
# 4                           2                      252
# ...                       ...                      ...
# 39691337                    7                     2187
# 39691338                    1                      118
# 39691339                    1                      114
# 39691340                    1                      114
# 39691341                    1                      118
#
#           session_i_tt_frame_length  session_o_tt_frame_length  udp_tt_length  \
# 0                              66.0                        NaN            NaN
# 1                            1019.0                     1002.0            NaN
# 2                            1327.0                     2171.0            NaN
# 3                             132.0                      120.0            NaN
# 4                             132.0                      120.0            NaN
# ...                             ...                        ...            ...
# 39691337                     1148.0                     1039.0            NaN
# 39691338                       58.0                       60.0            NaN
# 39691339                       54.0                       60.0            NaN
# 39691340                       54.0                       60.0            NaN
# 39691341                       58.0                       60.0            NaN
#
#           udp_i_tt_length  udp_o_tt_length  udp_i_avg_length  \
# 0                     NaN              NaN               NaN
# 1                     NaN              NaN               NaN
# 2                     NaN              NaN               NaN
# 3                     NaN              NaN               NaN
# 4                     NaN              NaN               NaN
# ...                   ...              ...               ...
# 39691337              NaN              NaN               NaN
# 39691338              NaN              NaN               NaN
# 39691339              NaN              NaN               NaN
# 39691340              NaN              NaN               NaN
# 39691341              NaN              NaN               NaN
#
#           udp_o_avg_length  icmp_i_avg_length  icmp_o_avg_length  \
# 0                      NaN                NaN                NaN
# 1                      NaN                NaN                NaN
# 2                      NaN                NaN                NaN
# 3                      NaN                NaN                NaN
# 4                      NaN                NaN                NaN
# ...                    ...                ...                ...
# 39691337               NaN                NaN                NaN
# 39691338               NaN                NaN                NaN
# 39691339               NaN                NaN                NaN
# 39691340               NaN                NaN                NaN
# 39691341               NaN                NaN                NaN
#
#           icmp_tt_original_datagram_length  icmp_i_tt_datagram_length  \
# 0                                      NaN                        NaN
# 1                                      NaN                        NaN
# 2                                      NaN                        NaN
# 3                                      NaN                        NaN
# 4                                      NaN                        NaN
# ...                                    ...                        ...
# 39691337                               NaN                        NaN
# 39691338                               NaN                        NaN
# 39691339                               NaN                        NaN
# 39691340                               NaN                        NaN
# 39691341                               NaN                        NaN
#
#           icmp_o_tt_datagram_length  icmp_i_avg_datagram_length  \
# 0                               NaN                         NaN
# 1                               NaN                         NaN
# 2                               NaN                         NaN
# 3                               NaN                         NaN
# 4                               NaN                         NaN
# ...                             ...                         ...
# 39691337                        NaN                         NaN
# 39691338                        NaN                         NaN
# 39691339                        NaN                         NaN
# 39691340                        NaN                         NaN
# 39691341                        NaN                         NaN
#
#           icmp_o_avg_datagram_length  tcp_tt_payload_length  \
# 0                                NaN                    0.0
# 1                                NaN                  819.0
# 2                                NaN                 1450.0
# 3                                NaN                    0.0
# 4                                NaN                    0.0
# ...                              ...                    ...
# 39691337                         NaN                 1247.0
# 39691338                         NaN                    0.0
# 39691339                         NaN                    0.0
# 39691340                         NaN                    0.0
# 39691341                         NaN                    0.0
#
#           tcp_i_tt_payload_length  tcp_o_tt_payload_length  \
# 0                             0.0                      NaN
# 1                           455.0                    364.0
# 2                           647.0                    803.0
# 3                             0.0                      0.0
# 4                             0.0                      0.0
# ...                           ...                      ...
# 39691337                    678.0                    569.0
# 39691338                      0.0                      0.0
# 39691339                      0.0                      0.0
# 39691340                      0.0                      0.0
# 39691341                      0.0                      0.0
#
#           tcp_i_avg_payload_length  tcp_o_avg_payload_length          ip_src  \
# 0                         0.000000                       NaN     1.0.139.246
# 1                        45.500000                 33.090909     1.0.158.208
# 2                        53.916667                 34.913043      1.0.205.50
# 3                         0.000000                  0.000000      1.0.243.72
# 4                         0.000000                  0.000000      1.1.132.18
# ...                            ...                       ...             ...
# 39691337                 96.857143                 81.285714   99.172.74.218
# 39691338                  0.000000                  0.000000  99.229.179.186
# 39691339                  0.000000                  0.000000   99.231.161.73
# 39691340                  0.000000                  0.000000  99.234.116.255
# 39691341                  0.000000                  0.000000    99.86.163.99
#
#                    ip_dst  tcp_srcport  tcp_dstport  udp_srcport  udp_dstport  \
# 0          210.242.146.60       8121.0        445.0          NaN          NaN
# 1          210.242.148.66      61655.0        445.0          NaN          NaN
# 2          210.242.146.76      64514.0        445.0          NaN          NaN
# 3         210.242.145.133      57876.0        445.0          NaN          NaN
# 4         210.242.148.223      20569.0        445.0          NaN          NaN
# ...                   ...          ...          ...          ...          ...
# 39691337  210.242.146.201      56640.0         22.0          NaN          NaN
# 39691338  210.242.146.106      30798.0         23.0          NaN          NaN
# 39691339   210.242.148.93      23549.0         23.0          NaN          NaN
# 39691340  210.242.146.151      40542.0       8080.0          NaN          NaN
# 39691341  210.242.145.205        443.0      17634.0          NaN          NaN
#
#                 country                 city         subdivisions  \
# 0              Thailand            Chon Buri            Chon Buri
# 1              Thailand                 None                 None
# 2              Thailand          Phitsanulok          Phitsanulok
# 3              Thailand  Nakhon Si Thammarat  Nakhon Si Thammarat
# 4              Thailand              Bangkok              Bangkok
# ...                 ...                  ...                  ...
# 39691337  United States                Miami              Florida
# 39691338         Canada        Richmond Hill              Ontario
# 39691339         Canada            Pickering              Ontario
# 39691340         Canada             Brampton              Ontario
# 39691341  United States                 None                 None
#
#                    domain                isp frame_i_common_protocols  \
# 0         totinternet.net                TOT     eth:ethertype:ip:tcp
# 1         totinternet.net                TOT     eth:ethertype:ip:tcp
# 2         totinternet.net                TOT     eth:ethertype:ip:tcp
# 3         totinternet.net                TOT     eth:ethertype:ip:tcp
# 4         totinternet.net                TOT     eth:ethertype:ip:tcp
# ...                   ...                ...                      ...
# 39691337    sbcglobal.net       AT&T U-verse     eth:ethertype:ip:tcp
# 39691338       rogers.com       Rogers Cable     eth:ethertype:ip:tcp
# 39691339       rogers.com       Rogers Cable     eth:ethertype:ip:tcp
# 39691340       rogers.com       Rogers Cable     eth:ethertype:ip:tcp
# 39691341   cloudfront.net  Amazon CloudFront     eth:ethertype:ip:tcp
#
#          frame_o_common_protocols          frame_i_max_protocols  \
# 0                            None           eth:ethertype:ip:tcp
# 1            eth:ethertype:ip:tcp  eth:ethertype:ip:tcp:nbss:smb
# 2            eth:ethertype:ip:tcp  eth:ethertype:ip:tcp:nbss:smb
# 3            eth:ethertype:ip:tcp           eth:ethertype:ip:tcp
# 4            eth:ethertype:ip:tcp           eth:ethertype:ip:tcp
# ...                           ...                            ...
# 39691337     eth:ethertype:ip:tcp       eth:ethertype:ip:tcp:ssh
# 39691338     eth:ethertype:ip:tcp           eth:ethertype:ip:tcp
# 39691339     eth:ethertype:ip:tcp           eth:ethertype:ip:tcp
# 39691340     eth:ethertype:ip:tcp           eth:ethertype:ip:tcp
# 39691341     eth:ethertype:ip:tcp           eth:ethertype:ip:tcp
#
#                   frame_o_max_protocols  \
# 0                                  None
# 1         eth:ethertype:ip:tcp:nbss:smb
# 2         eth:ethertype:ip:tcp:nbss:smb
# 3                  eth:ethertype:ip:tcp
# 4                  eth:ethertype:ip:tcp
# ...                                 ...
# 39691337       eth:ethertype:ip:tcp:ssh
# 39691338           eth:ethertype:ip:tcp
# 39691339           eth:ethertype:ip:tcp
# 39691340           eth:ethertype:ip:tcp
# 39691341           eth:ethertype:ip:tcp
#
#                                          tcp_i_payload_list  \
# 0                                                        []
# 1         [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 2         [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 3                                                        []
# 4                                                        []
# ...                                                     ...
# 39691337  [[3:DfQMPmfK7PATwqv6OpVE:DPQKJqpu, 1578571782....
# 39691338                                                 []
# 39691339                                                 []
# 39691340                                                 []
# 39691341                                                 []
#
#                                          tcp_o_payload_list
# 0                                                        []
# 1         [[6:iCV00dYMe9hNV9o7dEdoa0VfCy/a9evgfey9FV1RG/...
# 2         [[6:iCV00dYMe9hNV9o7dEdoa0VfCy/a9evgfey9FV1RG/...
# 3                                                        []
# 4                                                        []
# ...                                                     ...
# 39691337  [[48:u4GahchAheMAM8FMyGlMZheuelx7JU2MZheuelx7J...
# 39691338                                                 []
# 39691339                                                 []
# 39691340                                                 []
# 39691341                                                 []
#
# [39691342 rows x 43 columns]

# %%
# df_fil = df[['session_time','session_time_list','session_duration','session_tt_packet', 'session_i_tt_packet', 'session_o_tt_packet',
#              'session_tt_frame_length', 'session_i_tt_frame_length','session_o_tt_frame_length','udp_tt_length', 'udp_i_tt_length',
#              'udp_o_tt_length', 'udp_i_avg_length', 'udp_o_avg_length','icmp_i_avg_length', 'icmp_o_avg_length',
#              'icmp_tt_original_datagram_length', 'icmp_i_tt_datagram_length','icmp_o_tt_datagram_length', 'icmp_i_avg_datagram_length',
#              'icmp_o_avg_datagram_length','tcp_tt_payload_length', 'tcp_i_tt_payload_length','tcp_o_tt_payload_length', 'tcp_i_avg_payload_length',
#              'tcp_o_avg_payload_length','ip_src', 'ip_dst','tcp_srcport', 'tcp_dstport', 'udp_srcport', 'udp_dstport', 'country',
#              'city', 'subdivisions','domain','frame_i_common_protocols','frame_o_common_protocols', 'frame_i_max_protocols','frame_o_max_protocols', 'tcp_i_payload_list', 'tcp_o_payload_list'        
#             ]]
# df_fil = df_fil.to_pandas()
# gc.colect()
# df_fil
# Out:
# /opt/spark/python/pyspark/sql/dataframe.py:2222: UserWarning: toPandas attempted Arrow optimization because 'spark.sql.execution.arrow.pyspark.enabled' is set to true, but has reached the error below and can not continue. Note that 'spark.sql.execution.arrow.pyspark.fallback.enabled' does not have an effect on failures in the middle of computation.
#   An error occurred while calling o1820.getResult.
# : org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:227)
# 	at org.apache.spark.security.SocketAuthServer.getResult(SocketAuthServer.scala:88)
# 	at org.apache.spark.security.SocketAuthServer.getResult(SocketAuthServer.scala:84)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)
# Caused by: org.apache.spark.SparkException: Job aborted due to stage failure: Total size of serialized results of 60 tasks (20.2 GiB) is bigger than spark.driver.maxResultSize (20.0 GiB)
# 	at org.apache.spark.scheduler.DAGScheduler.failJobAndIndependentStages(DAGScheduler.scala:1989)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$abortStage$2(DAGScheduler.scala:1977)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$abortStage$2$adapted(DAGScheduler.scala:1976)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.DAGScheduler.abortStage(DAGScheduler.scala:1976)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$handleTaskSetFailed$1(DAGScheduler.scala:956)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$handleTaskSetFailed$1$adapted(DAGScheduler.scala:956)
# 	at scala.Option.foreach(Option.scala:407)
# 	at org.apache.spark.scheduler.DAGScheduler.handleTaskSetFailed(DAGScheduler.scala:956)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.doOnReceive(DAGScheduler.scala:2206)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:2155)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:2144)
# 	at org.apache.spark.util.EventLoop$$anon$1.run(EventLoop.scala:49)
# 	at org.apache.spark.scheduler.DAGScheduler.runJob(DAGScheduler.scala:758)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2116)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2211)
# 	at org.apache.spark.sql.Dataset.$anonfun$collectAsArrowToPython$5(Dataset.scala:3410)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1377)
# 	at org.apache.spark.sql.Dataset.$anonfun$collectAsArrowToPython$2(Dataset.scala:3414)
# 	at org.apache.spark.sql.Dataset.$anonfun$collectAsArrowToPython$2$adapted(Dataset.scala:3391)
# 	at org.apache.spark.security.SocketAuthServer$.$anonfun$serveToStream$2(SocketAuthServer.scala:130)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1377)
# 	at org.apache.spark.security.SocketAuthServer$.$anonfun$serveToStream$1(SocketAuthServer.scala:132)
# 	at org.apache.spark.security.SocketAuthServer$.$anonfun$serveToStream$1$adapted(SocketAuthServer.scala:127)
# 	at org.apache.spark.security.SocketFuncServer.handleConnection(SocketAuthServer.scala:104)
# 	at org.apache.spark.security.SocketFuncServer.handleConnection(SocketAuthServer.scala:98)
# 	at org.apache.spark.security.SocketAuthServer$$anon$1.$anonfun$run$1(SocketAuthServer.scala:60)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.security.SocketAuthServer$$anon$1.run(SocketAuthServer.scala:60)
#
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-7-1a69eefe161e> in <module>
#       7              'city', 'subdivisions','domain','frame_i_common_protocols','frame_o_common_protocols', 'frame_i_max_protocols','frame_o_max_protocols', 'tcp_i_payload_list', 'tcp_o_payload_list'
#       8             ]]
# ----> 9 df_fil = df_fil.to_pandas()
#      10 gc.colect()
#      11 df_fil
#
# ~/anaconda3/lib/python3.7/site-packages/databricks/koalas/frame.py in to_pandas(self)
#    4821         3   0.2   0.1
#    4822         """
# -> 4823         return self._internal.to_pandas_frame.copy()
#    4824
#    4825     # Alias to maintain backward compatibility with Spark
#
# ~/anaconda3/lib/python3.7/site-packages/databricks/koalas/utils.py in _lazy_property(self)
#     430     def _lazy_property(self):
#     431         if not hasattr(self, attr_name):
# --> 432             setattr(self, attr_name, fn(self))
#     433         return getattr(self, attr_name)
#     434
#
# ~/anaconda3/lib/python3.7/site-packages/databricks/koalas/internal.py in to_pandas_frame(self)
#     797         """ Return as pandas DataFrame. """
#     798         sdf = self.to_internal_spark_frame
# --> 799         pdf = sdf.toPandas()
#     800         if len(pdf) == 0 and len(sdf.schema) > 0:
#     801             pdf = pdf.astype(
#
# /opt/spark/python/pyspark/sql/dataframe.py in toPandas(self)
#    2200                     from pyspark.sql.types import _check_dataframe_localize_timestamps
#    2201                     import pyarrow
# -> 2202                     batches = self._collectAsArrow()
#    2203                     if len(batches) > 0:
#    2204                         table = pyarrow.Table.from_batches(batches)
#
# /opt/spark/python/pyspark/sql/dataframe.py in _collectAsArrow(self)
#    2314         finally:
#    2315             # Join serving thread and raise any exceptions from collectAsArrowToPython
# -> 2316             jsocket_auth_server.getResult()
#    2317
#    2318         # Separate RecordBatches from batch order indices in results
#
# /opt/spark/python/lib/py4j-0.10.8.1-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1284         answer = self.gateway_client.send_command(command)
#    1285         return_value = get_return_value(
# -> 1286             answer, self.gateway_client, self.target_id, self.name)
#    1287
#    1288         for temp_arg in temp_args:
#
# /opt/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      96     def deco(*a, **kw):
#      97         try:
# ---> 98             return f(*a, **kw)
#      99         except py4j.protocol.Py4JJavaError as e:
#     100             converted = convert_exception(e.java_exception)
#
# /opt/spark/python/lib/py4j-0.10.8.1-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     326                 raise Py4JJavaError(
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#     330                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling o1820.getResult.
# : org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:227)
# 	at org.apache.spark.security.SocketAuthServer.getResult(SocketAuthServer.scala:88)
# 	at org.apache.spark.security.SocketAuthServer.getResult(SocketAuthServer.scala:84)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)
# Caused by: org.apache.spark.SparkException: Job aborted due to stage failure: Total size of serialized results of 60 tasks (20.2 GiB) is bigger than spark.driver.maxResultSize (20.0 GiB)
# 	at org.apache.spark.scheduler.DAGScheduler.failJobAndIndependentStages(DAGScheduler.scala:1989)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$abortStage$2(DAGScheduler.scala:1977)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$abortStage$2$adapted(DAGScheduler.scala:1976)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.DAGScheduler.abortStage(DAGScheduler.scala:1976)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$handleTaskSetFailed$1(DAGScheduler.scala:956)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$handleTaskSetFailed$1$adapted(DAGScheduler.scala:956)
# 	at scala.Option.foreach(Option.scala:407)
# 	at org.apache.spark.scheduler.DAGScheduler.handleTaskSetFailed(DAGScheduler.scala:956)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.doOnReceive(DAGScheduler.scala:2206)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:2155)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:2144)
# 	at org.apache.spark.util.EventLoop$$anon$1.run(EventLoop.scala:49)
# 	at org.apache.spark.scheduler.DAGScheduler.runJob(DAGScheduler.scala:758)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2116)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2211)
# 	at org.apache.spark.sql.Dataset.$anonfun$collectAsArrowToPython$5(Dataset.scala:3410)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1377)
# 	at org.apache.spark.sql.Dataset.$anonfun$collectAsArrowToPython$2(Dataset.scala:3414)
# 	at org.apache.spark.sql.Dataset.$anonfun$collectAsArrowToPython$2$adapted(Dataset.scala:3391)
# 	at org.apache.spark.security.SocketAuthServer$.$anonfun$serveToStream$2(SocketAuthServer.scala:130)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1377)
# 	at org.apache.spark.security.SocketAuthServer$.$anonfun$serveToStream$1(SocketAuthServer.scala:132)
# 	at org.apache.spark.security.SocketAuthServer$.$anonfun$serveToStream$1$adapted(SocketAuthServer.scala:127)
# 	at org.apache.spark.security.SocketFuncServer.handleConnection(SocketAuthServer.scala:104)
# 	at org.apache.spark.security.SocketFuncServer.handleConnection(SocketAuthServer.scala:98)
# 	at org.apache.spark.security.SocketAuthServer$$anon$1.$anonfun$run$1(SocketAuthServer.scala:60)
# 	at scala.util.Try$.apply(Try.scala:213)
# 	at org.apache.spark.security.SocketAuthServer$$anon$1.run(SocketAuthServer.scala:60)

# %%
 #篩選出有in bound payload的session
df1 = df[(df.session_duration>0.1)&(df.session_i_tt_packet>1)&(df.session_i_tt_frame_length>0)&
         (df.tcp_i_payload_list.astype(str)!='[]')]
df1 = df1[(df1.udp_i_tt_length>0)|(df1.udp_i_avg_length>0)|(df1.icmp_i_avg_length>0)|
        (df1.icmp_i_tt_datagram_length>0)|(df1.tcp_i_tt_payload_length>0)|(df1.tcp_i_avg_payload_length>0)]
gc.collect()
df1
# Out:
#           session_time                                  session_time_list  \
# 1         1.578565e+09  [1578564803.525677, 1578564806.728999, 1578564...
# 2         1.578555e+09  [1578554510.42924, 1578554510.42951, 157855451...
# 6         1.578556e+09  [1578556215.607608, 1578556215.60782, 15785562...
# 12        1.578581e+09  [1578581015.898646, 1578581015.8988, 157858101...
# 14        1.578576e+09  [1578575982.451519, 1578575982.451776, 1578575...
# ...                ...                                                ...
# 39691319  1.578565e+09  [1578564987.30598, 1578564990.320998, 15785649...
# 39691321  1.578549e+09  [1578549426.039548, 1578549426.039865, 1578549...
# 39691325  1.578503e+09  [1578503102.745177, 1578503102.745503, 1578503...
# 39691335  1.578539e+09  [1578538647.625036, 1578538647.625272, 1578538...
# 39691337  1.578572e+09  [1578571782.696612, 1578571782.696941, 1578571...
#
#           session_duration  session_tt_packet  session_i_tt_packet  \
# 1                10.781249                 21                   10
# 2                16.405455                 35                   12
# 6                 0.113164                  6                    3
# 12                0.113059                  6                    3
# 14                1.231880                 19                    8
# ...                    ...                ...                  ...
# 39691319         18.233986                  9                    7
# 39691321          0.787305                 15                    7
# 39691325          2.995025                 15                    8
# 39691335         16.597672                 11                    6
# 39691337          1.367122                 14                    7
#
#           session_o_tt_packet  session_tt_frame_length  \
# 1                          11                     2021
# 2                          23                     3498
# 6                           3                      448
# 12                          3                      497
# 14                         11                     1905
# ...                       ...                      ...
# 39691319                    2                      941
# 39691321                    8                     2116
# 39691325                    7                     2253
# 39691335                    5                     1015
# 39691337                    7                     2187
#
#           session_i_tt_frame_length  session_o_tt_frame_length  udp_tt_length  \
# 1                            1019.0                     1002.0            NaN
# 2                            1327.0                     2171.0            NaN
# 6                             262.0                      186.0            NaN
# 12                            311.0                      186.0            NaN
# 14                            899.0                     1006.0            NaN
# ...                             ...                        ...            ...
# 39691319                      821.0                      120.0            NaN
# 39691321                     1011.0                     1105.0            NaN
# 39691325                     1214.0                     1039.0            NaN
# 39691335                      611.0                      404.0            NaN
# 39691337                     1148.0                     1039.0            NaN
#
#           udp_i_tt_length  udp_o_tt_length  udp_i_avg_length  \
# 1                     NaN              NaN               NaN
# 2                     NaN              NaN               NaN
# 6                     NaN              NaN               NaN
# 12                    NaN              NaN               NaN
# 14                    NaN              NaN               NaN
# ...                   ...              ...               ...
# 39691319              NaN              NaN               NaN
# 39691321              NaN              NaN               NaN
# 39691325              NaN              NaN               NaN
# 39691335              NaN              NaN               NaN
# 39691337              NaN              NaN               NaN
#
#           udp_o_avg_length  icmp_i_avg_length  icmp_o_avg_length  \
# 1                      NaN                NaN                NaN
# 2                      NaN                NaN                NaN
# 6                      NaN                NaN                NaN
# 12                     NaN                NaN                NaN
# 14                     NaN                NaN                NaN
# ...                    ...                ...                ...
# 39691319               NaN                NaN                NaN
# 39691321               NaN                NaN                NaN
# 39691325               NaN                NaN                NaN
# 39691335               NaN                NaN                NaN
# 39691337               NaN                NaN                NaN
#
#           icmp_tt_original_datagram_length  icmp_i_tt_datagram_length  \
# 1                                      NaN                        NaN
# 2                                      NaN                        NaN
# 6                                      NaN                        NaN
# 12                                     NaN                        NaN
# 14                                     NaN                        NaN
# ...                                    ...                        ...
# 39691319                               NaN                        NaN
# 39691321                               NaN                        NaN
# 39691325                               NaN                        NaN
# 39691335                               NaN                        NaN
# 39691337                               NaN                        NaN
#
#           icmp_o_tt_datagram_length  icmp_i_avg_datagram_length  \
# 1                               NaN                         NaN
# 2                               NaN                         NaN
# 6                               NaN                         NaN
# 12                              NaN                         NaN
# 14                              NaN                         NaN
# ...                             ...                         ...
# 39691319                        NaN                         NaN
# 39691321                        NaN                         NaN
# 39691325                        NaN                         NaN
# 39691335                        NaN                         NaN
# 39691337                        NaN                         NaN
#
#           icmp_o_avg_datagram_length  tcp_tt_payload_length  \
# 1                                NaN                  819.0
# 2                                NaN                 1450.0
# 6                                NaN                   88.0
# 12                               NaN                  137.0
# 14                               NaN                  819.0
# ...                              ...                    ...
# 39691319                         NaN                  411.0
# 39691321                         NaN                 1110.0
# 39691325                         NaN                 1247.0
# 39691335                         NaN                  297.0
# 39691337                         NaN                 1247.0
#
#           tcp_i_tt_payload_length  tcp_o_tt_payload_length  \
# 1                           455.0                    364.0
# 2                           647.0                    803.0
# 6                            88.0                      0.0
# 12                          137.0                      0.0
# 14                          455.0                    364.0
# ...                           ...                      ...
# 39691319                    411.0                      0.0
# 39691321                    541.0                    569.0
# 39691325                    678.0                    569.0
# 39691335                    231.0                     66.0
# 39691337                    678.0                    569.0
#
#           tcp_i_avg_payload_length  tcp_o_avg_payload_length         ip_src  \
# 1                        45.500000                 33.090909    1.0.158.208
# 2                        53.916667                 34.913043     1.0.205.50
# 6                        29.333333                  0.000000    1.1.171.230
# 12                       45.666667                  0.000000    1.1.219.197
# 14                       56.875000                 33.090909    1.1.219.197
# ...                            ...                       ...            ...
# 39691319                 58.714286                  0.000000  96.45.245.194
# 39691321                 77.285714                 71.125000  96.78.177.242
# 39691325                 84.750000                 81.285714  97.64.250.178
# 39691335                 38.500000                 13.200000  98.155.96.170
# 39691337                 96.857143                 81.285714  99.172.74.218
#
#                    ip_dst  tcp_srcport  tcp_dstport  udp_srcport  udp_dstport  \
# 1          210.242.148.66      61655.0        445.0          NaN          NaN
# 2          210.242.146.76      64514.0        445.0          NaN          NaN
# 6          210.242.148.95      63615.0        445.0          NaN          NaN
# 12        210.242.149.126      14893.0        445.0          NaN          NaN
# 14         210.242.149.79       1790.0        445.0          NaN          NaN
# ...                   ...          ...          ...          ...          ...
# 39691319   210.242.147.55      57558.0        445.0          NaN          NaN
# 39691321  210.242.145.238      35740.0         22.0          NaN          NaN
# 39691325  210.242.145.193      35435.0         22.0          NaN          NaN
# 39691335  210.242.148.183       3420.0         80.0          NaN          NaN
# 39691337  210.242.146.201      56640.0         22.0          NaN          NaN
#
#                 country           city subdivisions               domain  \
# 1              Thailand           None         None      totinternet.net
# 2              Thailand    Phitsanulok  Phitsanulok      totinternet.net
# 6              Thailand     Chiang Mai   Chiang Mai      totinternet.net
# 12             Thailand       Yasothon     Yasothon      totinternet.net
# 14             Thailand       Yasothon     Yasothon      totinternet.net
# ...                 ...            ...          ...                  ...
# 39691319  United States           Lima         Ohio       brightohio.net
# 39691321  United States  San Francisco   California  comcastbusiness.net
# 39691325  United States        Greenup     Illinois            mchsi.com
# 39691335  United States     Kaunakakai       Hawaii               rr.com
# 39691337  United States          Miami      Florida        sbcglobal.net
#
#                        isp frame_i_common_protocols frame_o_common_protocols  \
# 1                      TOT     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 2                      TOT     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 6                      TOT     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 12                     TOT     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 14                     TOT     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# ...                    ...                      ...                      ...
# 39691319           Com Net     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 39691321  Comcast Business     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 39691325    Mediacom Cable     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 39691335          Spectrum     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 39691337      AT&T U-verse     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
#
#                   frame_i_max_protocols          frame_o_max_protocols  \
# 1         eth:ethertype:ip:tcp:nbss:smb  eth:ethertype:ip:tcp:nbss:smb
# 2         eth:ethertype:ip:tcp:nbss:smb  eth:ethertype:ip:tcp:nbss:smb
# 6         eth:ethertype:ip:tcp:nbss:smb           eth:ethertype:ip:tcp
# 12        eth:ethertype:ip:tcp:nbss:smb           eth:ethertype:ip:tcp
# 14        eth:ethertype:ip:tcp:nbss:smb  eth:ethertype:ip:tcp:nbss:smb
# ...                                 ...                            ...
# 39691319  eth:ethertype:ip:tcp:nbss:smb           eth:ethertype:ip:tcp
# 39691321       eth:ethertype:ip:tcp:ssh       eth:ethertype:ip:tcp:ssh
# 39691325       eth:ethertype:ip:tcp:ssh       eth:ethertype:ip:tcp:ssh
# 39691335      eth:ethertype:ip:tcp:http      eth:ethertype:ip:tcp:http
# 39691337       eth:ethertype:ip:tcp:ssh       eth:ethertype:ip:tcp:ssh
#
#                                          tcp_i_payload_list  \
# 1         [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 2         [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 6         [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 12        [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 14        [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# ...                                                     ...
# 39691319  [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 39691321  [[3:DfQMPmfK7PATaupm:DPQKtupm, 1578549426.3346...
# 39691325  [[3:DfQMPmfK7PATwqv6OpVE:DPQKJqpu, 1578503102....
# 39691335  [[12:DC779Xdykq16Bn6R7o6sD/XmHXqrI2ErB5cuXNQNc...
# 39691337  [[3:DfQMPmfK7PATwqv6OpVE:DPQKJqpu, 1578571782....
#
#                                          tcp_o_payload_list
# 1         [[6:iCV00dYMe9hNV9o7dEdoa0VfCy/a9evgfey9FV1RG/...
# 2         [[6:iCV00dYMe9hNV9o7dEdoa0VfCy/a9evgfey9FV1RG/...
# 6                                                        []
# 12                                                       []
# 14        [[6:iCV00dYMe9hNV9o7dEdoa0VfCy/a9evgfey9FV1RG/...
# ...                                                     ...
# 39691319                                                 []
# 39691321  [[3:DfQMPmflfTAfQW4Y7wUY6ljrA6EkvA6HfQNun:DPQl...
# 39691325  [[48:ubpahchAheMAM8FMyGlMZheuelx7JU2MZheuelx7J...
# 39691335  [[6:KKA7fXXX7Uj+SVXTBHE7RWf6Q9ZTR66T7Dhmn:KX7f...
# 39691337  [[48:u4GahchAheMAM8FMyGlMZheuelx7JU2MZheuelx7J...
#
# [8555268 rows x 43 columns]

# %%
df2 = df1[(df1.tcp_o_payload_list.astype(str)!='[]')&(df1.session_o_tt_packet>0)&(df1.session_o_tt_frame_length>0)]
df2 = df2[(df2.udp_o_tt_length>0)|(df2.udp_o_avg_length>0)|(df2.icmp_o_avg_length>0)|
        (df2.icmp_o_tt_datagram_length>0)|(df2.tcp_o_tt_payload_length>0)|(df2.tcp_o_avg_payload_length>0)]
df2 = df2[(df2.domain != 'googlebot.com')|(df2.isp!='Googlebot')]
gc.collect()
df2
# Out:
#           session_time                                  session_time_list  \
# 1         1.578565e+09  [1578564803.525677, 1578564806.728999, 1578564...
# 2         1.578555e+09  [1578554510.42924, 1578554510.42951, 157855451...
# 14        1.578576e+09  [1578575982.451519, 1578575982.451776, 1578575...
# 16        1.578559e+09  [1578559471.751642, 1578559471.751921, 1578559...
# 18        1.578562e+09  [1578561609.806994, 1578561609.807307, 1578561...
# ...                ...                                                ...
# 39691307  1.578521e+09  [1578520959.426729, 1578520959.426993, 1578520...
# 39691321  1.578549e+09  [1578549426.039548, 1578549426.039865, 1578549...
# 39691325  1.578503e+09  [1578503102.745177, 1578503102.745503, 1578503...
# 39691335  1.578539e+09  [1578538647.625036, 1578538647.625272, 1578538...
# 39691337  1.578572e+09  [1578571782.696612, 1578571782.696941, 1578571...
#
#           session_duration  session_tt_packet  session_i_tt_packet  \
# 1                10.781249                 21                   10
# 2                16.405455                 35                   12
# 14                1.231880                 19                    8
# 16                1.191147                 18                    8
# 18                1.711502                 14                    6
# ...                    ...                ...                  ...
# 39691307          6.920641                 20                    8
# 39691321          0.787305                 15                    7
# 39691325          2.995025                 15                    8
# 39691335         16.597672                 11                    6
# 39691337          1.367122                 14                    7
#
#           session_o_tt_packet  session_tt_frame_length  \
# 1                          11                     2021
# 2                          23                     3498
# 14                         11                     1905
# 16                         10                     1628
# 18                          8                     1400
# ...                       ...                      ...
# 39691307                   12                     2084
# 39691321                    8                     2116
# 39691325                    7                     2253
# 39691335                    5                     1015
# 39691337                    7                     2187
#
#           session_i_tt_frame_length  session_o_tt_frame_length  udp_tt_length  \
# 1                            1019.0                     1002.0            NaN
# 2                            1327.0                     2171.0            NaN
# 14                            899.0                     1006.0            NaN
# 16                            808.0                      820.0            NaN
# 18                            700.0                      700.0            NaN
# ...                             ...                        ...            ...
# 39691307                      899.0                     1185.0            NaN
# 39691321                     1011.0                     1105.0            NaN
# 39691325                     1214.0                     1039.0            NaN
# 39691335                      611.0                      404.0            NaN
# 39691337                     1148.0                     1039.0            NaN
#
#           udp_i_tt_length  udp_o_tt_length  udp_i_avg_length  \
# 1                     NaN              NaN               NaN
# 2                     NaN              NaN               NaN
# 14                    NaN              NaN               NaN
# 16                    NaN              NaN               NaN
# 18                    NaN              NaN               NaN
# ...                   ...              ...               ...
# 39691307              NaN              NaN               NaN
# 39691321              NaN              NaN               NaN
# 39691325              NaN              NaN               NaN
# 39691335              NaN              NaN               NaN
# 39691337              NaN              NaN               NaN
#
#           udp_o_avg_length  icmp_i_avg_length  icmp_o_avg_length  \
# 1                      NaN                NaN                NaN
# 2                      NaN                NaN                NaN
# 14                     NaN                NaN                NaN
# 16                     NaN                NaN                NaN
# 18                     NaN                NaN                NaN
# ...                    ...                ...                ...
# 39691307               NaN                NaN                NaN
# 39691321               NaN                NaN                NaN
# 39691325               NaN                NaN                NaN
# 39691335               NaN                NaN                NaN
# 39691337               NaN                NaN                NaN
#
#           icmp_tt_original_datagram_length  icmp_i_tt_datagram_length  \
# 1                                      NaN                        NaN
# 2                                      NaN                        NaN
# 14                                     NaN                        NaN
# 16                                     NaN                        NaN
# 18                                     NaN                        NaN
# ...                                    ...                        ...
# 39691307                               NaN                        NaN
# 39691321                               NaN                        NaN
# 39691325                               NaN                        NaN
# 39691335                               NaN                        NaN
# 39691337                               NaN                        NaN
#
#           icmp_o_tt_datagram_length  icmp_i_avg_datagram_length  \
# 1                               NaN                         NaN
# 2                               NaN                         NaN
# 14                              NaN                         NaN
# 16                              NaN                         NaN
# 18                              NaN                         NaN
# ...                             ...                         ...
# 39691307                        NaN                         NaN
# 39691321                        NaN                         NaN
# 39691325                        NaN                         NaN
# 39691335                        NaN                         NaN
# 39691337                        NaN                         NaN
#
#           icmp_o_avg_datagram_length  tcp_tt_payload_length  \
# 1                                NaN                  819.0
# 2                                NaN                 1450.0
# 14                               NaN                  819.0
# 16                               NaN                  596.0
# 18                               NaN                  596.0
# ...                              ...                    ...
# 39691307                         NaN                  944.0
# 39691321                         NaN                 1110.0
# 39691325                         NaN                 1247.0
# 39691335                         NaN                  297.0
# 39691337                         NaN                 1247.0
#
#           tcp_i_tt_payload_length  tcp_o_tt_payload_length  \
# 1                           455.0                    364.0
# 2                           647.0                    803.0
# 14                          455.0                    364.0
# 16                          364.0                    232.0
# 18                          364.0                    232.0
# ...                           ...                      ...
# 39691307                    455.0                    489.0
# 39691321                    541.0                    569.0
# 39691325                    678.0                    569.0
# 39691335                    231.0                     66.0
# 39691337                    678.0                    569.0
#
#           tcp_i_avg_payload_length  tcp_o_avg_payload_length         ip_src  \
# 1                        45.500000                 33.090909    1.0.158.208
# 2                        53.916667                 34.913043     1.0.205.50
# 14                       56.875000                 33.090909    1.1.219.197
# 16                       45.500000                 23.200000    1.1.219.248
# 18                       60.666667                 29.000000    1.1.230.225
# ...                            ...                       ...            ...
# 39691307                 56.875000                 40.750000    96.10.81.36
# 39691321                 77.285714                 71.125000  96.78.177.242
# 39691325                 84.750000                 81.285714  97.64.250.178
# 39691335                 38.500000                 13.200000  98.155.96.170
# 39691337                 96.857143                 81.285714  99.172.74.218
#
#                    ip_dst  tcp_srcport  tcp_dstport  udp_srcport  udp_dstport  \
# 1          210.242.148.66      61655.0        445.0          NaN          NaN
# 2          210.242.146.76      64514.0        445.0          NaN          NaN
# 14         210.242.149.79       1790.0        445.0          NaN          NaN
# 16         210.242.147.73      23196.0        445.0          NaN          NaN
# 18         210.242.147.88      64688.0        445.0          NaN          NaN
# ...                   ...          ...          ...          ...          ...
# 39691307   210.242.146.75      58451.0        445.0          NaN          NaN
# 39691321  210.242.145.238      35740.0         22.0          NaN          NaN
# 39691325  210.242.145.193      35435.0         22.0          NaN          NaN
# 39691335  210.242.148.183       3420.0         80.0          NaN          NaN
# 39691337  210.242.146.201      56640.0         22.0          NaN          NaN
#
#                 country           city    subdivisions               domain  \
# 1              Thailand           None            None      totinternet.net
# 2              Thailand    Phitsanulok     Phitsanulok      totinternet.net
# 14             Thailand       Yasothon        Yasothon      totinternet.net
# 16             Thailand       Yasothon        Yasothon      totinternet.net
# 18             Thailand     Chaiyaphum      Chaiyaphum      totinternet.net
# ...                 ...            ...             ...                  ...
# 39691307  United States   Kernersville  North Carolina               rr.com
# 39691321  United States  San Francisco      California  comcastbusiness.net
# 39691325  United States        Greenup        Illinois            mchsi.com
# 39691335  United States     Kaunakakai          Hawaii               rr.com
# 39691337  United States          Miami         Florida        sbcglobal.net
#
#                         isp frame_i_common_protocols frame_o_common_protocols  \
# 1                       TOT     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 2                       TOT     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 14                      TOT     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 16                      TOT     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 18                      TOT     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# ...                     ...                      ...                      ...
# 39691307  Spectrum Business     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 39691321   Comcast Business     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 39691325     Mediacom Cable     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 39691335           Spectrum     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 39691337       AT&T U-verse     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
#
#                   frame_i_max_protocols          frame_o_max_protocols  \
# 1         eth:ethertype:ip:tcp:nbss:smb  eth:ethertype:ip:tcp:nbss:smb
# 2         eth:ethertype:ip:tcp:nbss:smb  eth:ethertype:ip:tcp:nbss:smb
# 14        eth:ethertype:ip:tcp:nbss:smb  eth:ethertype:ip:tcp:nbss:smb
# 16        eth:ethertype:ip:tcp:nbss:smb  eth:ethertype:ip:tcp:nbss:smb
# 18        eth:ethertype:ip:tcp:nbss:smb  eth:ethertype:ip:tcp:nbss:smb
# ...                                 ...                            ...
# 39691307  eth:ethertype:ip:tcp:nbss:smb  eth:ethertype:ip:tcp:nbss:smb
# 39691321       eth:ethertype:ip:tcp:ssh       eth:ethertype:ip:tcp:ssh
# 39691325       eth:ethertype:ip:tcp:ssh       eth:ethertype:ip:tcp:ssh
# 39691335      eth:ethertype:ip:tcp:http      eth:ethertype:ip:tcp:http
# 39691337       eth:ethertype:ip:tcp:ssh       eth:ethertype:ip:tcp:ssh
#
#                                          tcp_i_payload_list  \
# 1         [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 2         [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 14        [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 16        [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 18        [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# ...                                                     ...
# 39691307  [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 39691321  [[3:DfQMPmfK7PATaupm:DPQKtupm, 1578549426.3346...
# 39691325  [[3:DfQMPmfK7PATwqv6OpVE:DPQKJqpu, 1578503102....
# 39691335  [[12:DC779Xdykq16Bn6R7o6sD/XmHXqrI2ErB5cuXNQNc...
# 39691337  [[3:DfQMPmfK7PATwqv6OpVE:DPQKJqpu, 1578571782....
#
#                                          tcp_o_payload_list
# 1         [[6:iCV00dYMe9hNV9o7dEdoa0VfCy/a9evgfey9FV1RG/...
# 2         [[6:iCV00dYMe9hNV9o7dEdoa0VfCy/a9evgfey9FV1RG/...
# 14        [[6:iCV00dYMe9hNV9o7dEdoa0VfCy/a9evgfey9FV1RG/...
# 16        [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# 18        [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# ...                                                     ...
# 39691307  [[6:iCV00dYMe9hNV9o7dEdoa0VfCy/a9evgfey9FV1RG/...
# 39691321  [[3:DfQMPmflfTAfQW4Y7wUY6ljrA6EkvA6HfQNun:DPQl...
# 39691325  [[48:ubpahchAheMAM8FMyGlMZheuelx7JU2MZheuelx7J...
# 39691335  [[6:KKA7fXXX7Uj+SVXTBHE7RWf6Q9ZTR66T7Dhmn:KX7f...
# 39691337  [[48:u4GahchAheMAM8FMyGlMZheuelx7JU2MZheuelx7J...
#
# [2983293 rows x 43 columns]

# %%
print(df2.domain.value_counts().head(60))
df2.isp.value_counts().head(60)
# Out:
# hinet.net                        403936
# netvigator.com                    99571
# dvois.com                         76370
# elcat.kg                          55807
# brasiltelecom.net.br              48058
# mediana.net.ua                    44645
# vnpt.vn                           39949
# wildpark.net                      29916
# corbina.ru                        29826
# cableonline.com.mx                28966
# viettel.vn                        23523
# cantv.net                         22869
# actcorp.in                        22575
# veetime.com                       21961
# btc-net.bg                        19089
# pldt.net                          13751
# 163data.com.cn                    13083
# tedata.net                        12506
# ip-193-70-6.eu                    11604
# ip-94-23-145.eu                   10751
# telkom.net.id                      9151
# linode.com                         8430
# multi.net.pk                       7031
# nexlinx.net.pk                     6357
# totinternet.net                    5994
# bashtel.ru                         5278
# ttnet.com.tr                       4828
# prod-infinitum.com.mx              4545
# ip-51-91-212.eu                    3815
# sify.net                           3542
# no-reverse-dns-configured.com      3497
# magticom.ge                        3482
# gvt.net.br                         3288
# steadfastdns.net                   2981
# comcast.net                        2888
# iam.net.ma                         2888
# telecomitalia.it                   2530
# googleusercontent.com              2503
# telesp.net.br                      2319
# in.th                              2248
# amazonaws.com                      2202
# 3bb.co.th                          2168
# rr.com                             2150
# ovo.sc                             2110
# vnpt-hanoi.com.vn                  2023
# uninet-ide.com.mx                  2019
# gov.br                             2019
# bsnl.in                            1818
# airtelbroadband.in                 1806
# totalplay.net                      1649
# etb.net.co                         1594
# in-addr.arpa                       1557
# yota.ru                            1551
# une.net.co                         1488
# netsystemsresearch.com             1477
# censys.io                          1448
# superonline.net                    1435
# cnt-grms.ec                        1369
# 49-tataidc.co.in                   1342
# balifiber.id                       1285
# Name: domain, dtype: int64
# 10526028  Beijing Baidu Netcom Science and Technology Co.
# 13904722  Beijing Baidu Netcom Science and Technology Co.
# 19459651  Beijing Baidu Netcom Science and Technology Co.
# 20057341  Beijing Baidu Netcom Science and Technology Co.
# 22639887  Beijing Baidu Netcom Science and Technology Co.
# 23233563  Beijing Baidu Netcom Science and Technology Co.
# 23630981  Beijing Baidu Netcom Science and Technology Co.
# 24027701  Beijing Baidu Netcom Science and Technology Co.
# 24423690  Beijing Baidu Netcom Science and Technology Co.
# 25811496  Beijing Baidu Netcom Science and Technology Co.
# 26999213  Beijing Baidu Netcom Science and Technology Co.
# 30171458  Beijing Baidu Netcom Science and Technology Co.
# 32949892  Beijing Baidu Netcom Science and Technology Co.
# 32949893  Beijing Baidu Netcom Science and Technology Co.
# 33543755  Beijing Baidu Netcom Science and Technology Co.
# 34338094  Beijing Baidu Netcom Science and Technology Co.
# 36519294  Beijing Baidu Netcom Science and Technology Co.
# 36519296  Beijing Baidu Netcom Science and Technology Co.
# 38899727  Beijing Baidu Netcom Science and Technology Co.
# 39296240  Beijing Baidu Netcom Science and Technology Co.
#
#          frame_i_common_protocols frame_o_common_protocols  \
# 1791037      eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 5759170      eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 9531977      eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 10526028     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 13904722     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 19459651     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 20057341     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 22639887     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 23233563     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 23630981     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 24027701     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 24423690     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 25811496     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 26999213     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 30171458     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 32949892     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 32949893     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 33543755     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 34338094     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 36519294     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 36519296     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 38899727     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 39296240     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
#
#                                    frame_i_max_protocols  \
# 1791037                   eth:ethertype:ip:tcp:http:data
# 5759170                        eth:ethertype:ip:tcp:http
# 9531977                   eth:ethertype:ip:tcp:http:data
# 10526028                            eth:ethertype:ip:tcp
# 13904722                       eth:ethertype:ip:tcp:http
# 19459651                       eth:ethertype:ip:tcp:http
# 20057341                       eth:ethertype:ip:tcp:http
# 22639887                  eth:ethertype:ip:tcp:http:data
# 23233563                  eth:ethertype:ip:tcp:http:data
# 23630981                       eth:ethertype:ip:tcp:http
# 24027701                       eth:ethertype:ip:tcp:http
# 24423690  eth:ethertype:ip:tcp:http:urlencoded-form:data
# 25811496                       eth:ethertype:ip:tcp:http
# 26999213                       eth:ethertype:ip:tcp:http
# 30171458                       eth:ethertype:ip:tcp:http
# 32949892                            eth:ethertype:ip:tcp
# 32949893                            eth:ethertype:ip:tcp
# 33543755                       eth:ethertype:ip:tcp:http
# 34338094                       eth:ethertype:ip:tcp:http
# 36519294                       eth:ethertype:ip:tcp:http
# 36519296                       eth:ethertype:ip:tcp:http
# 38899727  eth:ethertype:ip:tcp:http:urlencoded-form:data
# 39296240  eth:ethertype:ip:tcp:http:urlencoded-form:data
#
#                                    frame_o_max_protocols  \
# 1791037   eth:ethertype:ip:tcp:http:data-text-lines:data
# 5759170    eth:ethertype:ip:tcp:http:data-text-lines:xml
# 9531977    eth:ethertype:ip:tcp:http:data-text-lines:xml
# 10526028                        eth:ethertype:ip:tcp:ssl
# 13904722   eth:ethertype:ip:tcp:http:data-text-lines:xml
# 19459651  eth:ethertype:ip:tcp:http:data-text-lines:data
# 20057341   eth:ethertype:ip:tcp:http:data-text-lines:xml
# 22639887                       eth:ethertype:ip:tcp:http
# 23233563   eth:ethertype:ip:tcp:http:data-text-lines:xml
# 23630981                       eth:ethertype:ip:tcp:http
# 24027701   eth:ethertype:ip:tcp:http:data-text-lines:xml
# 24423690   eth:ethertype:ip:tcp:http:data-text-lines:xml
# 25811496       eth:ethertype:ip:tcp:http:data-text-lines
# 26999213   eth:ethertype:ip:tcp:http:data-text-lines:xml
# 30171458   eth:ethertype:ip:tcp:http:data-text-lines:xml
# 32949892       eth:ethertype:ip:tcp:http:data-text-lines
# 32949893   eth:ethertype:ip:tcp:http:data-text-lines:xml
# 33543755   eth:ethertype:ip:tcp:http:data-text-lines:xml
# 34338094   eth:ethertype:ip:tcp:http:data-text-lines:xml
# 36519294                       eth:ethertype:ip:tcp:http
# 36519296                       eth:ethertype:ip:tcp:http
# 38899727   eth:ethertype:ip:tcp:http:data-text-lines:xml
# 39296240   eth:ethertype:ip:tcp:http:data-text-lines:xml
#
#                                          tcp_i_payload_list  \
# 1791037   [[48:te4nVjhjjhX3QBFqFoauuZbMMzmD18hw18hBt2qj5...
# 5759170   [[12:GdBr7TspQifuPRCk4XIWpNECO4XIWpNECR72sNEYi...
# 9531977   [[12:TqIHXqocuDWk4XIWpNECO4XIWpNECR72sNEYi/sNu...
# 10526028  [[12:1Qw1b7sV9k4XIWpNECO4XIWpNECR72sNEYi/sNuHX...
# 13904722  [[48:FT28bid17zsLW4FLVjhjjhX3PaTkISkn3Km99oxtF...
# 19459651  [[48:FT28bid17zsLW4FLVjhjjhX3PaTkISkn3Km99oxtF...
# 20057341  [[12:A9AkxsLTsXh+wbv3Wfrk4XIWpNECO4XIWpNECR72s...
# 22639887  [[48:te4nVjhjjhX3QBFqFoauuZbMMzmD18hw18hBt2qj5...
# 23233563  [[48:te4nVjhjjhX3QBFqFoauuZbMMzmD18hw18hBt2qj5...
# 23630981  [[12:A9uSsTsGEk4XIWpNECO4XIWpNECR72sNEYi/sNuHX...
# 24027701  [[12:G2oLk4XIWpNECO4XIWpNECR72sNEYi/sNuHXqSm:z...
# 24423690  [[48:8+BguvaC06HtMz2qsyhOY18nmVjhjjhX3B:8+OnzS...
# 25811496  [[12:GifaXmgvRDviUeupfvXIWdNkUlGHeupfvXIWdNkUO...
# 26999213  [[12:GdBr7TspQifuPRCk4XIWpNECO4XIWpNECR72sNEYi...
# 30171458  [[12:YcDgfk4XIWpNECO4XIWpNECR72sNEYi/sNuHXq6xc...
# 32949892  [[48:QauY18nNqwdkJmemVjhjjhX3Zm5ZxJnr4/pzO:eY1...
# 32949893  [[12:YcDgfk4XIWpNECO4XIWpNECR72sNEYi/sNuHXq6xc...
# 33543755  [[12:7KekUx7Wjaxk4XIWpNECO4XIWpNECR72sNEYi/sN8...
# 34338094  [[12:7KekUx7Wjaxk4XIWpNECO4XIWpNECR72sNEYi/sN8...
# 36519294  [[24:TfaRERRadVJpN/jJpN/NRNUENAnRRaSRVlAaw9cOF...
# 36519296  [[12:YcDgfk4XIWpNECO4XIWpNECR72sNEYi/sNuHXq6xc...
# 38899727  [[48:8+BguvaC06HtMz2qsyhOY18nmVjhjjhX3B:8+OnzS...
# 39296240  [[48:8+sN1aF6HMMzg18hw18kZqLqx3Km7Y18nNdVjhjjh...
#
#                                          tcp_o_payload_list
# 1791037   [[24:KPfcE7SadNCYb5miImFQh4b7Q2gZX82+L7H6EN6H:...
# 5759170   [[3:KD+U/kIgfFf+S5aPS:KKAk7flea, 1578572491.42...
# 9531977   [[3:KD+U/kIgfFf+S5aPS:KKAk7flea, 1578511923.32...
# 10526028  [[3:11V1V1V1V1V1V1V1V1V1V1V1V1V1V1V1V1V1V1V1V1...
# 13904722  [[3:KD+U/kIgfFf+S5aPS:KKAk7flea, 1578539545.63...
# 19459651  [[24:KPfcE7SadNCYb5miImFQh4b7Q2gZX82+L7H6EN6H:...
# 20057341  [[3:KD+U/kIgfFf+S5aPS:KKAk7flea, 1578545278.72...
# 22639887  [[6:KKA7fXXX7Uj+SVXTBHE7RWf6Q9ZTR66T7Dhmn:KX7f...
# 23233563  [[3:KD+U/kIgfFf+S5aPS:KKAk7flea, 1578558525.36...
# 23630981  [[6:KKA7fXXX7Uj+SVXTBHE7RWf6Q9ZTR66T7Dhmn:KX7f...
# 24027701  [[3:KD+U/kIgfFf+S5aPS:KKAk7flea, 1578511749.40...
# 24423690  [[3:KD+U/kIgfFf+S5aPS:KKAk7flea, 1578547572.29...
# 25811496  [[6:KKAC1XQu7qam9TR9Rn+xPTBHE7RWf6Q9ZTRBT7DO7E...
# 26999213  [[3:KD+U/kIgfFf+S5aPS:KKAk7flea, 1578510343.13...
# 30171458  [[3:KD+U/kIgfFf+S5aPS:KKAk7flea, 1578561705.65...
# 32949892  [[6:KKAC1XQu7qam9TR9Rn+xPTBHE7RWf6Q9ZTRBT7DO7E...
# 32949893  [[3:KD+U/kIgfFf+S5aPS:KKAk7flea, 1578505553.83...
# 33543755  [[3:KD+U/kIgfFf+S5aPS:KKAk7flea, 1578578611.45...
# 34338094  [[3:KD+U/kIgfFf+S5aPS:KKAk7flea, 1578505382.87...
# 36519294  [[6:KKA7fXXX7Uj+SVXTBHE7RWf6Q9ZTR66T7Dhmn:KX7f...
# 36519296  [[6:KKA7fXXX7Uj+SVXTBHE7RWf6Q9ZTR66T7Dhmn:KX7f...
# 38899727  [[3:KD+U/kIgfFf+S5aPS:KKAk7flea, 1578510151.66...
# 39296240  [[3:KD+U/kIgfFf+S5aPS:KKAk7flea, 1578525568.72...

# %% [markdown]
# http

# %%
http_df, http_df_payload = prepare_df(df2,'http')
http_big_dict = similarity_compare(http_df,http_df_payload)
gc.collect() #05:38
# Out:
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100%|██████████| 143412/143412 [02:09<00:00, 1103.68it/s]
# 0

# %%
def cluster_stat(protocol_big_dict,protocol_df):
    """
    GOAL: output statistic of certain protocol
    input1: dict from similarity_compare
    inpit2: df from prepare_df
    """
    
    all_nums = []
    clus_id = []
    # all_num = 0
    for k,v in protocol_big_dict.items():
    #     all_nums.extend(v)
        all_nums.append(len(v))
        clus_id.append(k)
    #     all_num +=len(v)
    clus_num = len(all_nums)
    print("原本總共sessions#:",len(protocol_df))
    print("共有#sessions可分群:",sum(all_nums)+clus_num,"共有#lonerSessions:",len(protocol_df)-(sum(all_nums)+clus_num))
    print("可分為#群:",clus_num)
#     print(sum(all_nums)+len(all_nums),len(protocol_df)-(sum(all_nums)+len(all_nums)),len(protocol_df))
    protocol_stat_df = pd.DataFrame(all_nums,index=clus_id)
    protocol_stat_df[0] = protocol_stat_df[0]+1
    print("前五大的cluster key與對應之群集大小\n",protocol_stat_df[0].nlargest(5))
    print(protocol_stat_df.describe())
    protocol_stat_df.hist(bins=40)
    
cluster_stat(http_big_dict,http_df) #可分為#群: 159 共有#sessions可分群: 143363 共有#lonerSessions: 49
# Out:
# 原本總共sessions#: 143412
# 共有#sessions可分群: 143378 共有#lonerSessions: 34
# 可分為#群: 148
# 前五大的cluster key與對應之群集大小
#  996      39160
# 997      30666
# 575      23308
# 3370     10765
# 17522     9276
# Name: 0, dtype: int64
#                   0
# count    148.000000
# mean     968.770270
# std     4663.838347
# min        2.000000
# 25%        4.000000
# 50%        9.000000
# 75%       53.000000
# max    39160.000000

# %%
# pickle_dir = '/home/antslab/123_antslab/spark_data/pcap_inter/2020_01_09/中華電信/case_pickles/'
write2pkl(http_df,http_big_dict,996,"http_1")
write2pkl(http_df,http_big_dict,997,"http_2")
write2pkl(http_df,http_big_dict,575,"http_3")
write2pkl(http_df,http_big_dict,3370,"http_4")
write2pkl(http_df,http_big_dict,17522,"http_5")

# %%
min(all_nums),max(all_nums),np.mean(all_nums),np.std(all_nums),np.median(all_nums)
# Out:
# (1, 76986, 1344.4293785310736, 7011.119688363667, 13.0)

# %%
http_big_dict[92]
# Out:
# [2145,
#  3775,
#  22808,
#  22808,
#  22808,
#  22808,
#  22808,
#  22808,
#  22808,
#  22826,
#  22827,
#  22897,
#  22897,
#  22903,
#  22904,
#  27663,
#  37470,
#  37488,
#  37490,
#  37496,
#  37501,
#  73634,
#  73635,
#  73636,
#  79455,
#  83804,
#  83804,
#  83804,
#  83804,
#  83804,
#  83804,
#  114647,
#  117656,
#  120864,
#  121012,
#  121012,
#  133764,
#  133764,
#  133764,
#  133764,
#  133764,
#  133764,
#  141256,
#  167991,
#  173330,
#  253107,
#  253111,
#  255177,
#  255665,
#  264295,
#  264295,
#  264320,
#  275866,
#  275867,
#  275868,
#  275871,
#  275871,
#  275871,
#  275964,
#  275964,
#  275964,
#  275964,
#  280809,
#  290527,
#  290538,
#  326957,
#  326962,
#  326966,
#  326971,
#  337100,
#  337119,
#  337184,
#  337195,
#  337840,
#  337841,
#  367182,
#  372537,
#  378143,
#  386659,
#  386659,
#  386659,
#  420641,
#  432687,
#  435242,
#  507702,
#  507762,
#  508814,
#  508815,
#  528624,
#  528636,
#  528637,
#  528699,
#  528732,
#  528740,
#  543035,
#  543043,
#  543050,
#  579473,
#  579844,
#  590317,
#  590320,
#  590320,
#  590320,
#  617920,
#  625459,
#  645971,
#  656271,
#  672305,
#  672308,
#  687108,
#  760024,
#  760024,
#  760030,
#  760036,
#  780933,
#  780997,
#  781011,
#  781025,
#  781030,
#  781030,
#  781030,
#  781030,
#  781030,
#  783352,
#  795580,
#  795582,
#  795624,
#  795627,
#  831839,
#  831845,
#  870700,
#  898106,
#  898106,
#  898106,
#  898106,
#  924356,
#  942560,
#  942569,
#  1009562,
#  1009566,
#  1009566,
#  1009566,
#  1009566,
#  1009566,
#  1012196,
#  1013655,
#  1013656,
#  1020718,
#  1020718,
#  1020718,
#  1020718,
#  1032335,
#  1032353,
#  1032443,
#  1032457,
#  1032458,
#  1037238,
#  1037239,
#  1046965,
#  1046984,
#  1134966,
#  1141817,
#  1141931,
#  1149776,
#  1175900,
#  1261279,
#  1261281,
#  1261288,
#  1261292,
#  1261309,
#  1261309,
#  1261309,
#  1261309,
#  1261309,
#  1261309,
#  1265275,
#  1265323,
#  1272280,
#  1284087,
#  1284087,
#  1284087,
#  1284087,
#  1284087,
#  1284097,
#  1284111,
#  1284180,
#  1284181,
#  1287896,
#  1288916,
#  1298604,
#  1298613,
#  1298616,
#  1298631,
#  1298648,
#  1334607,
#  1334616,
#  1334620,
#  1344680,
#  1345349,
#  1346373,
#  1380388,
#  1401514,
#  1402047,
#  1402047,
#  1402047,
#  1402047,
#  1402047,
#  1427809,
#  1440151,
#  1513455,
#  1513514,
#  1515654,
#  1515654,
#  1515654,
#  1515654,
#  1515654,
#  1515654,
#  1516151,
#  1517543,
#  1517544,
#  1536365,
#  1551165,
#  1551173,
#  1551175,
#  1551181,
#  1587413,
#  1627046,
#  1628408,
#  1638411,
#  1646758,
#  1646758,
#  1646758,
#  1680703,
#  1680704,
#  1760016,
#  1766280,
#  1768416,
#  1768416,
#  1768416,
#  1768468,
#  1777470,
#  1777470,
#  1789138,
#  1789140,
#  1789144,
#  1789144,
#  1789206,
#  1794070,
#  1794098,
#  1801703,
#  1803759,
#  1803764,
#  1803791,
#  1850225,
#  1886280,
#  1886280,
#  1886280,
#  1886280,
#  1886491,
#  1886491,
#  1886491,
#  1886491,
#  1886896,
#  1886896,
#  1886896,
#  1886896,
#  1886896,
#  1891874,
#  1897962,
#  1906739,
#  1906739,
#  1906739,
#  1906739,
#  1906739,
#  1906739,
#  1906739,
#  1933848,
#  1933848,
#  1933848,
#  1933848,
#  1933848,
#  1933848,
#  1948634,
#  1951752,
#  2019402,
#  2022050,
#  2022050,
#  2032033,
#  2042809,
#  2042809,
#  2042809,
#  2042809,
#  2042809,
#  2042809,
#  2042809,
#  2042809,
#  2042809,
#  2042811,
#  2042811,
#  2042811,
#  2042811,
#  2042811,
#  2042869,
#  2042869,
#  2042869,
#  2042869,
#  2047626,
#  2047626,
#  2047626,
#  2047626,
#  2047626,
#  2047626,
#  2050236,
#  2057278,
#  2057279,
#  2057281,
#  2057295,
#  2057295,
#  2057300,
#  2057313,
#  2057330,
#  2104078,
#  2137585,
#  2138629,
#  2138629,
#  2138629,
#  2138629,
#  2138629,
#  2138629,
#  2138629,
#  2138629,
#  2138629,
#  2138629,
#  2140957,
#  2149986,
#  2149986,
#  2158863,
#  2198215,
#  2200682,
#  2294502,
#  2294507,
#  2294507,
#  2294507,
#  2294507,
#  2294507,
#  2294507,
#  2294570,
#  2294570,
#  2294570,
#  2294570,
#  2294570,
#  2294570,
#  2294585,
#  2294592,
#  2308766,
#  2308771,
#  2308785,
#  2308818,
#  2344920,
#  2354515,
#  2355794,
#  2382767,
#  2396066,
#  2396066,
#  2396066,
#  2396066,
#  2396066,
#  2396066,
#  2405016,
#  2405016,
#  2407486,
#  2408034,
#  2437232,
#  2437234,
#  2524118,
#  2524118,
#  2524118,
#  2524118,
#  2524118,
#  5183501,
#  5183501,
#  5183501,
#  5210116,
#  5210116,
#  5210158,
#  5210162,
#  5224604,
#  5255482,
#  5318048,
#  5318051,
#  5318051,
#  5318051,
#  5318051,
#  5318058,
#  5318059,
#  5318060,
#  5318161,
#  5318163,
#  5318163,
#  5318163,
#  5318163,
#  5318163,
#  5332429,
#  5332459,
#  5332459,
#  5368711,
#  5368712,
#  5413746,
#  5413746,
#  5413746,
#  5413746,
#  5413746,
#  5413746,
#  5414905,
#  5417136,
#  5430514,
#  5432823,
#  5462024,
#  5506112,
#  5549028,
#  5558074,
#  5558076,
#  5558086,
#  5558086,
#  5558093,
#  5570147,
#  5570148,
#  5570149,
#  5570191,
#  5584485,
#  5584516,
#  5672961,
#  5679158,
#  5679165,
#  5679165,
#  5679165,
#  5683414,
#  5686865,
#  5686865,
#  5686865,
#  5686865,
#  5686865,
#  5686865,
#  5686865,
#  5688238,
#  5792325,
#  5792361,
#  5809483,
#  5821671,
#  5821746,
#  5826283,
#  5826284,
#  5834016,
#  5836086,
#  5836096,
#  5836104,
#  5836117,
#  5872179,
#  5882287,
#  5883116,
#  5883116,
#  5883116,
#  5883116,
#  5883116,
#  5883116,
#  5883116,
#  5909648,
#  5917413,
#  5923388,
#  5923388,
#  5923388,
#  5923388,
#  5923388,
#  5923388,
#  5923388,
#  5923388,
#  5948992,
#  5964814,
#  5965279,
#  5970052,
#  6044104,
#  6050163,
#  6050163,
#  6050163,
#  6050163,
#  6052226,
#  6073587,
#  6086025,
#  6088064,
#  6088073,
#  6088087,
#  6124466,
#  6134709,
#  6201618,
#  6235935,
#  6305532,
#  6326098,
#  6326166,
#  6340571,
#  6340574,
#  6340579,
#  6340606,
#  6376701,
#  6376706,
#  6416253,
#  6416253,
#  6416253,
#  6416253,
#  6416253,
#  6416253,
#  6421866,
#  6421866,
#  6421866,
#  6421866,
#  6421866,
#  6424348,
#  6430924,
#  6434919,
#  6434919,
#  6434919,
#  6434919,
#  6434919,
#  6456902,
#  6469060,
#  6481122,
#  6481122,
#  6481122,
#  6483818,
#  6548161,
#  6565429,
#  6577263,
#  6577264,
#  6577330,
#  6591736,
#  6591743,
#  6591762,
#  6591762,
#  6591762,
#  6628367,
#  6628368,
#  6638291,
#  6638997,
#  6666097,
#  6666741,
#  6674688,
#  6674688,
#  6674688,
#  6674688,
#  6674688,
#  6674688,
#  6674688,
#  6675728,
#  6679880,
#  6679880,
#  6683188,
#  6687484,
#  6687484,
#  6687484,
#  6687484,
#  6687484,
#  6687484,
#  6691463,
#  6721656,
#  6721659,
#  ...]

# %%
sum(all_nums)
# Out:
# 419623

# %%
# def split_col_len(session):
#     '''
#     input: list(session) of lists(packets) =>tuple=(hash,time)
    
#     Return1: list of ssdeep length
#     Return2: list of session's packets hashes
#     '''
# #     for session in payload_li:
#     packet_payload = []
#     packet_len = []
#     for packet in session:
#         ssdeep_hash = packet[0]
# #         packet_payload.append(ssdeep_hash)
#         packet_len.append(ssdeep_hash.split(':')[0])
#     return packet_len#,packet_payload

# def split_col_hash(session):
#     '''
#     input: list(session) of lists(packets) =>tuple=(hash,time)
    
#     Return1: list of ssdeep length
#     Return2: list of session's packets hashes
#     '''
# #     for session in payload_li:
#     packet_payload = []
#     packet_len = []
#     for packet in session:
#         ssdeep_hash = packet[0]
#         packet_payload.append(ssdeep_hash)
# #         packet_len.append(ssdeep_hash.split(':')[0])
#     return packet_payload

# %%
# df2_http_payload = df2_http[['tcp_i_payload_list']]
# df2_http_payload['size'] = df2_http_payload.tcp_i_payload_list.map(split_col_len) #,df2_http_payload['hash']
# df2_http_payload['hash'] = df2_http_payload.tcp_i_payload_list.map(split_col_hash)
# L_size = [x if isinstance(x, list) else [x] for x in df2_http_payload['size']]
# L_hash = [x if isinstance(x, list) else [x] for x in df2_http_payload['hash']]
# df2_http_payload = pd.DataFrame({
#     'idx':df2_http_payload.index.values.repeat([len(x) for x in L_size]),
#     'size':list(chain.from_iterable(L_size)),
#     'hash':list(chain.from_iterable(L_hash))
#     })
# # df2_http_payload['idx'] = 
# df2_http_payload['size'] = df2_http_payload['size'].astype(int)
# df2_http_payload
# Out:
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#              idx  size                                               hash
# 0             92     6  6:rHKAqEDxghMRo5auSGy6A7WfXl3Nupfh/aEjmjmn:rHX...
# 1             92     6  6:rHKAqEDxghMRo5auSGy6A7WfXl3Nupfh/aEjmjmn:rHX...
# 2             92     6  6:rHKAqEDxghMRo5auSGy6A7WfXl3Nupfh/aEjmjmn:rHX...
# 3             92     6  6:rHKAqEDxghMRo5auSGy6A7WfXl3Nupfh/aEjmjmn:rHX...
# 4             92     6  6:rHKAqEDxghMRo5auSGy6A7WfXl3Nupfh/aEjmjmn:rHX...
# ...          ...   ...                                                ...
# 336089  50455495    12  12:rHXqzNkZfcqL6xmMReH1JNkH18YH14NIL18YH1IyESu...
# 336090  50461064    12  12:DC779Xdykq16Bn6R7o6sD/XmHXqrI2ErB5cuXNQNcxY...
# 336091  50461202     3                                 3:cRm5tD+U/2:rHKA2
# 336092  50461202     3                                     3:Sfrfun:Sfrmn
# 336093  50461555    12  12:rHXq6xmMReT2eIs0+R56Y1awh5UP+/4D7eiMJNkZr1N...
#
# [336094 rows x 3 columns]

# %%
# def ssdeep_compare(target_hash,candidate_df):
#     '''
#     Input1: string of hash
#     Input2: dataframe of candidate
#     '''
#     def compare(candidate_hash):
#         return ssdeep.compare(target_hash,candidate_hash)
#     return candidate_df.hash.map(compare)
# big_dict_http = {}
# used_idx_li = []
# for idx in tqdm(df2_http.index):
#     if idx in used_idx_li:
#         continue
#     target = df2_http_payload[df2_http_payload.idx == idx]
#     target = target.reset_index(drop=True)
#     t_len = len(target)
#     q1 = int(t_len*0.25)
#     q2 = int(t_len*0.5)
#     q3 = int(t_len*0.75)
#     t_q1 = target.iloc[q1,-1]
#     t_q2 = target.iloc[q2,-1]
#     t_q3 = target.iloc[q3,-1]
#     candidate = df2_http_payload[df2_http_payload.idx>idx]
#     candidate['idx'] = candidate.idx.astype(str)
#     candidate_q1 = candidate[candidate['size']==target.iloc[q1,-2]]
#     candidate['q1'] = ssdeep_compare(t_q1,candidate_q1)
#     candidate_q2 = candidate[candidate['size']==target.iloc[q2,-2]]
#     candidate['q2'] = ssdeep_compare(t_q2,candidate_q2)
#     candidate_q3 = candidate[candidate['size']==target.iloc[q3,-2]]
#     candidate['q3'] = ssdeep_compare(t_q3,candidate_q3)
#     candidate = candidate.drop(['size','hash'],axis=1)
#     candidate['score'] = candidate.max(axis=1)
#     candidate = candidate[candidate.score>=40] #相似度分數，數字越小速度愈快、數字越大越多群
#     candidate['idx'] = candidate.idx.astype(int)
#     idx_li = candidate.idx.tolist()
#     if len(idx_li)>0:
#         big_dict_http[idx] = idx_li
#         used_idx_li.extend(idx_li)
#         used_idx_li = list(set(used_idx_li))
# #     candidate_q2 = 
    
    
# #     break
# #     candidate =
# Out:
#   0%|          | 0/238178 [00:00<?, ?it/s]/home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100%|██████████| 238178/238178 [11:47<00:00, 336.84it/s]

# %% [markdown]
# 畫distribution
# * 針對某單一case進行

# %%
def case_study(idx,payload_df):
    '''
    idx: which index is the dataframe's target?
    payload_df: protocol payload dataframe (packet-based)
    下面有一些參數可以改 (line19~23、27註解處)
    
    Return: Big dict
    '''
    big_dict = {}
    idx = int(idx)
    target = payload_df[payload_df.idx == idx]
    target = target.reset_index(drop=True)
    t_len = len(target)
    t_q1 = target.iloc[int(t_len*0.25),-1]
    t_q2 = target.iloc[int(t_len*0.5),-1]
    t_q3 = target.iloc[int(t_len*0.75),-1]
    candidate = payload_df[payload_df.idx != idx]
    candidate['idx'] = candidate.idx.astype(str)
    candidate_q1 = candidate[candidate['size']==target.iloc[int(t_len*0.25),-2]] #是否要match: match改成== 不match改成!=
    candidate['q1'] = ssdeep_compare(t_q1,candidate_q1)
    candidate_q2 = candidate[candidate['size']==target.iloc[int(t_len*0.5),-2]] # == or != (score=0)
    candidate['q2'] = ssdeep_compare(t_q2,candidate_q2)
    candidate_q3 = candidate[candidate['size']==target.iloc[int(t_len*0.75),-2]] #要找不像的時候要改成!=
    candidate['q3'] = ssdeep_compare(t_q3,candidate_q3)
    candidate = candidate.drop(['size','hash'],axis=1)
    candidate['score'] = candidate.max(axis=1)
    candidate = candidate[candidate.score>0] #相似度分數，數字越小速度愈快、數字越大越多群。要抓出幾分的人> == <
    candidate['idx'] = candidate.idx.astype(int)
    idx_li = candidate.idx.tolist()
    if len(idx_li)>0:
        big_dict[idx] = idx_li
    # len(big_dict.keys())
    print("所有該protocol與所給定之target的分數種類:",candidate.score.unique())
    print("總session數量:",len(big_dict[idx]))
    print("分數的分布:",candidate.score.value_counts().sort_index())
    print("分數的分布圖:",candidate.score.hist(bins=25))
    return big_dict, candidate

# %%
candidate.score.value_counts().sort_index()#.sum()
# Out:
# 40.0     1
# 41.0     2
# 43.0    14
# 44.0    14
# 46.0     2
# 47.0    87
# 49.0    14
# 50.0    52
# 52.0     1
# 54.0    51
# 55.0     7
# 57.0    67
# 58.0    12
# 60.0    79
# 61.0    22
# 63.0    72
# 65.0    41
# 66.0    67
# 68.0    52
# 69.0    38
# 71.0    47
# 72.0    25
# 74.0    27
# 75.0    10
# 77.0    10
# 79.0     9
# 80.0    15
# 82.0     8
# 83.0    16
# 85.0     4
# 86.0    11
# 88.0     9
# 90.0     3
# 91.0     4
# 94.0     2
# Name: score, dtype: int64

# %%
print(candidate.score.hist(bins=25))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
candidate.score.describe()
# Out:
# count    895.000000
# mean      62.375419
# std       10.893108
# min       40.000000
# 25%       54.000000
# 50%       63.000000
# 75%       69.000000
# max       94.000000
# Name: score, dtype: float64

# %%
def save_wireshark(df2_protocol,pkl_name,only_one=False):
    '''
    GOAL: save frame time list to pkl for Jerry to output wireshark pcap
    df2_protocol: protocol original dataframe (session-based)
    '''
    protocol_thr = df2_protocol.loc[big_dict_sqlmap[idx]]
    # protocol_thr = df2_protocol.loc[80891]  #也可只輸出一個特定sessiono的time frame list就好
    protocol_thr = protocol_thr.session_time_list.tolist()
    if not only_one:
        protocol_thr = [list(x) for x in protocol_thr]
    pickle.dump(obj=protocol_thr,file=open(pickle_dir+str(pkl_name)+'.pkl','wb'))
    print("總共具有的sessions數量:",len(protocol_thr))
# protocol_thr

# %% [markdown]
# sql map http

# %%
df2_http[df2_http.ip_src == '190.92.5.158'].index
# Out:
# Int64Index([   80890,    80891,    80892,   334327,   334328,   334329,
#               334330,   334331,   334332,   334335,
#             ...
#             49785502, 50037370, 50037371, 50037372, 50290869, 50290870,
#             50290871, 50290872, 50290873, 50290874],
#            dtype='int64', length=819)

# %%
for k,v in big_dict_http.items():
    if 80891 in v:
        print(k)
        break
# Out:
# 2394

# %%
case1_diagram = df2_http.loc[list(set(big_dict_http[2394]))]
time_lists = case1_diagram.session_time_list.tolist()
time_lists = [list(x) for x in time_lists]
ips = case1_diagram.ip_src.tolist()
countries = case1_diagram.country.tolist()
print(len(countries),len(ips))
# pickle_dir = '/home/antslab/spark_data/pcap_inter/2020_01_10/中華電信/case_pickles/'
pickle.dump(obj=(time_lists,ips,countries),file=open(pickle_dir+'case#1_threetuples.pkl','wb'))
# Out:
# 905 905

# %%
case1_diagram.ip_src.unique()
# Out:
# array(['103.16.71.248', '117.1.16.131', '190.92.5.158', '109.198.110.234'],
#       dtype=object)

# %% [markdown]
# #### SAMBA payload

# %%
smb_df, smb_df_payload = prepare_df(df2,'smb')
smb_big_dict = similarity_compare(smb_df,smb_df_payload)
len(smb_big_dict.keys())
# Out:
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#  18%|█▊        | 94974/523516 [05:22<44:04, 162.04it/s]  IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
cluster_stat(smb_big_dict,smb_df)
# Out:
# 原本總共sessions#: 523516
# 共有#sessions可分群: 523515 共有#lonerSessions: 1
# 可分為#群: 2
# 前三大的cluster key與對應之群集大小
#  1        522532
# 21938       983
# Name: 0, dtype: int64
#                    0
# count       2.000000
# mean   261757.500000
# std    368790.834621
# min       983.000000
# 25%    131370.250000
# 50%    261757.500000
# 75%    392144.750000
# max    522532.000000

# %%
write2pkl(smb_df,smb_big_dict,1,"smb_1")
write2pkl(smb_df,smb_big_dict,21938,"smb_2")
# write2pkl(smb_df,smb_big_dict,,"smb_3")
# Out:
# Unique Country#: 136 Unique IP#: 9239 Session#: 522532
# Unique Country#: 37 Unique IP#: 139 Session#: 983

# %%
# def split_col_len(session):
#     '''
#     input: list(session) of lists(packets) =>tuple=(hash,time)
    
#     Return1: list of ssdeep length
#     Return2: list of session's packets hashes
#     '''
# #     for session in payload_li:
#     packet_payload = []
#     packet_len = []
#     for packet in session:
#         ssdeep_hash = packet[0]
# #         packet_payload.append(ssdeep_hash)
#         packet_len.append(ssdeep_hash.split(':')[0])
#     return packet_len#,packet_payload

# def split_col_hash(session):
#     '''
#     input: list(session) of lists(packets) =>tuple=(hash,time)
    
#     Return1: list of ssdeep length
#     Return2: list of session's packets hashes
#     '''
# #     for session in payload_li:
#     packet_payload = []
#     packet_len = []
#     for packet in session:
#         ssdeep_hash = packet[0]
#         packet_payload.append(ssdeep_hash)
# #         packet_len.append(ssdeep_hash.split(':')[0])
#     return packet_payload

# %%
# df2_smb = df2[(df2.frame_i_max_protocols.str.contains('smb'))&(df2.frame_o_max_protocols.str.contains('smb'))]
# df2_smb_payload = df2_smb[['tcp_i_payload_list']]
# df2_smb_payload['size'] = df2_smb_payload.tcp_i_payload_list.map(split_col_len) #,df2_smb_payload['hash']
# df2_smb_payload['hash'] = df2_smb_payload.tcp_i_payload_list.map(split_col_hash)
# L_size = [x if isinstance(x, list) else [x] for x in df2_smb_payload['size']]
# L_hash = [x if isinstance(x, list) else [x] for x in df2_smb_payload['hash']]
# df2_smb_payload = pd.DataFrame({
#     'idx':df2_smb_payload.index.values.repeat([len(x) for x in L_size]),
#     'size':list(chain.from_iterable(L_size)),
#     'hash':list(chain.from_iterable(L_hash))
#     })
# # df2_smb_payload['idx'] = 
# df2_smb_payload['size'] = df2_smb_payload['size'].astype(int)
# df2_smb_payload
# Out:
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#               idx  size                                               hash
# 0              10     6  6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcVIi...
# 1              10     6  6:9dsdwLW0Vf6IMXvS66cXvTrV1P/Y0Vf6IMXvS66cK/iC...
# 2              10     6  6:g+p51VudwOwMrV10KDBQf//sSAvSAUqYyEfEfEfVV:g+...
# 3              10     3  3:11R6T5gvXV1V1Udwa3vV1V1V1V1V1V1V1V1V1V133ffc...
# 4              11     6  6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcVIi...
# ...           ...   ...                                                ...
# 1452833  50461550     3  3:11R2f486fV1V1V1Ud2FV1V1V1V1V1V1V1V1V1V133fff...
# 1452834  50461562     6  6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcVIi...
# 1452835  50461562     6  6:9dsdwLW0Vf6IMXvS66cXvTrV1P/Y0Vf6IMXvS66cK/iC...
# 1452836  50461562     6  6:g+p51VudwOwMrV10KDBQf//sSAvSAUqYyEfEfEfVV:g+...
# 1452837  50461562     3  3:11R6T5gvXV1V1Udwa3vV1V1V1V1V1V1V1V1V1V133ffc...
#
# [1452838 rows x 3 columns]

# %%
# def ssdeep_compare(target_hash,candidate_df):
#     '''
#     Input1: string of hash
#     Input2: dataframe of candidate
#     '''
#     def compare(candidate_hash):
#         return ssdeep.compare(target_hash,candidate_hash)
#     return candidate_df.hash.map(compare)
# big_dict_smb = {}
# used_idx_li = []
# for idx in tqdm(df2_smb.index):
#     if idx in used_idx_li:
#         continue
#     target = df2_smb_payload[df2_smb_payload.idx == idx]
#     target = target.reset_index(drop=True)
#     t_len = len(target)
#     q1 = int(t_len*0.25)
#     q2 = int(t_len*0.5)
#     t_q1 = target.iloc[q1,-1]
#     candidate = df2_smb_payload[df2_smb_payload.idx>idx]
#     candidate['idx'] = candidate.idx.astype(str)
#     candidate_q1 = candidate[candidate['size']==target.iloc[q1,-2]]
#     candidate['q1'] = ssdeep_compare(t_q1,candidate_q1)
#     if q2 != q1:
#         t_q2 = target.iloc[q2,-1]
#         q3 = int(t_len*0.75)
#         candidate_q2 = candidate[candidate['size']==target.iloc[q2,-2]]
#         candidate['q2'] = ssdeep_compare(t_q2,candidate_q2)
#         if q3 != q2:
#             t_q3 = target.iloc[q3,-1]
#             candidate_q3 = candidate[candidate['size']==target.iloc[q3,-2]]
#             candidate['q3'] = ssdeep_compare(t_q3,candidate_q3)
#     candidate = candidate.drop(['size','hash'],axis=1)
#     candidate['score'] = candidate.max(axis=1)
#     candidate = candidate[candidate.score>=40] #相似度分數，數字越小速度愈快、數字越大越多群
#     candidate['idx'] = candidate.idx.astype(int)
#     idx_li = candidate.idx.tolist()
#     if len(idx_li)>0:
#         big_dict_smb[idx] = idx_li
#         used_idx_li.extend(idx_li)
#         used_idx_li = list(set(used_idx_li))
# Out:
#   0%|          | 0/352131 [00:00<?, ?it/s]/home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100%|██████████| 352131/352131 [14:09<00:00, 414.36it/s]

# %%
df2_smb[df2_smb.ip_src == '113.189.231.122']
# Out:
#           session_time                                  session_time_list  \
# 512421    1.578621e+09  [1578620529.412071, 1578620529.412273, 1578620...
# 3032491   1.578622e+09  [1578621628.633667, 1578621628.633879, 1578621...
# 4040632   1.578621e+09  [1578621227.633486, 1578621227.633716, 1578621...
# 6309898   1.578622e+09  [1578622269.756694, 1578622269.75692, 15786222...
# 6309899   1.578618e+09  [1578618069.221727, 1578618072.309224, 1578618...
# 6561208   1.578620e+09  [1578620021.157126, 1578620021.157317, 1578620...
# 7823475   1.578621e+09  [1578621362.046162, 1578621362.046305, 1578621...
# 8578784   1.578620e+09  [1578620402.607934, 1578620402.608125, 1578620...
# 10599251  1.578622e+09  [1578621632.779687, 1578621632.779855, 1578621...
# 10599252  1.578622e+09  [1578622142.657625, 1578622142.660158, 1578622...
# 13375661  1.578622e+09  [1578621756.253791, 1578621756.254159, 1578621...
# 14638192  1.578622e+09  [1578621886.901775, 1578621886.90205, 15786218...
# 17667106  1.578621e+09  [1578620973.812302, 1578620973.812492, 1578620...
# 19181031  1.578621e+09  [1578621354.838852, 1578621354.838971, 1578621...
# 21452732  1.578621e+09  [1578620802.949043, 1578620802.94921, 15786208...
# 22209383  1.578620e+09  [1578620155.409224, 1578620155.409429, 1578620...
# 24985279  1.578622e+09  [1578622018.922494, 1578622018.922722, 1578622...
# 25236917  1.578622e+09  [1578621505.352163, 1578621505.352348, 1578621...
# 25489053  1.578622e+09  [1578622018.22067, 1578622018.220902, 15786220...
# 26752387  1.578619e+09  [1578619021.454944, 1578619021.455195, 1578619...
# 27256006  1.578620e+09  [1578620148.289383, 1578620148.289754, 1578620...
# 27760343  1.578621e+09  [1578620810.00304, 1578620810.003259, 15786208...
# 22209383  eth:ethertype:ip:tcp:nbss:smb
# 24985279  eth:ethertype:ip:tcp:nbss:smb
# 25236917  eth:ethertype:ip:tcp:nbss:smb
# 25489053  eth:ethertype:ip:tcp:nbss:smb
# 26752387  eth:ethertype:ip:tcp:nbss:smb
# 27256006  eth:ethertype:ip:tcp:nbss:smb
# 27760343  eth:ethertype:ip:tcp:nbss:smb
# 28769555  eth:ethertype:ip:tcp:nbss:smb
# 28769556  eth:ethertype:ip:tcp:nbss:smb
# 30032921  eth:ethertype:ip:tcp:nbss:smb
# 30789201  eth:ethertype:ip:tcp:nbss:smb
# 31293419  eth:ethertype:ip:tcp:nbss:smb
# 33566344  eth:ethertype:ip:tcp:nbss:smb
# 33818432  eth:ethertype:ip:tcp:nbss:smb
# 35079741  eth:ethertype:ip:tcp:nbss:smb
# 35332519  eth:ethertype:ip:tcp:nbss:smb
# 37602330  eth:ethertype:ip:tcp:nbss:smb
# 38107271  eth:ethertype:ip:tcp:nbss:smb
# 38612349  eth:ethertype:ip:tcp:nbss:smb
# 38864522  eth:ethertype:ip:tcp:nbss:smb
# 42650314  eth:ethertype:ip:tcp:nbss:smb
# 42902529  eth:ethertype:ip:tcp:nbss:smb
# 43912103  eth:ethertype:ip:tcp:nbss:smb
# 45679327  eth:ethertype:ip:tcp:nbss:smb
# 45931170  eth:ethertype:ip:tcp:nbss:smb
# 48954357  eth:ethertype:ip:tcp:nbss:smb
#
#                                          tcp_i_payload_list  \
# 512421    [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 3032491   [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 4040632   [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 6309898   [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 6309899   [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 6561208   [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 7823475   [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 8578784   [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 10599251  [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 10599252  [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 13375661  [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 14638192  [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 17667106  [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 19181031  [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 21452732  [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 22209383  [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 24985279  [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 25236917  [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 25489053  [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 26752387  [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 27256006  [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 27760343  [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 28769555  [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 28769556  [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 30032921  [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 30789201  [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 31293419  [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 33566344  [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 33818432  [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 35079741  [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 35332519  [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 37602330  [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 38107271  [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 38612349  [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 38864522  [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 42650314  [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 42902529  [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 43912103  [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 45679327  [[6:wV08dY0TAqRARUbESX1qvasTgb+RpoedfFKXqEPdcV...
# 45931170  [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
# 48954357  [[3:11QRfDp03vV1V1Ud2FV1V1V1V1V1V1V1V1V1V1V1V1...
#
#                                          tcp_o_payload_list
# 512421    [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# 3032491   [[6:iCV00dYMe9hNV9oEyoa0VfCy/a9evgfey9FV1RG/5r...
# 4040632   [[6:iCV00dYMe9hNV9oEyoa0VfCy/a9evgfey9FV1RG/5r...
# 6309898   [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# 6309899   [[3:11QQoW503vV1V1cdxYvV1V1V1V1V1V1V1V1V1V1V1V...
# 6561208   [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# 7823475   [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# 8578784   [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# 10599251  [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# 10599252  [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# 13375661  [[6:iCV00dYMe9hNV9oEyoa0VfCy/a9evgfey9FV1RG/5r...
# 14638192  [[6:iCV00dYMe9hNV9oEyoa0VfCy/a9evgfey9FV1RG/5r...
# 17667106  [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# 19181031  [[6:iCV00dYMe9hNV9oEyoa0VfCy/a9evgfey9FV1RG/5r...
# 21452732  [[6:iCV00dYMe9hNV9oEyoa0VfCy/a9evgfey9FV1RG/5r...
# 22209383  [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# 24985279  [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# 25236917  [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# 25489053  [[6:iCV00dYMe9hNV9oEyoa0VfCy/a9evgfey9FV1RG/5r...
# 26752387  [[3:11QQoW503vV1V1cdxYvV1V1V1V1V1V1V1V1V1V1V1V...
# 27256006  [[6:iCV00dYMe9hNV9oEyoa0VfCy/a9evgfey9FV1RG/5r...
# 27760343  [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# 28769555  [[6:iCV00dYMe9hNV9oEyoa0VfCy/a9evgfey9FV1RG/5r...
# 28769556  [[6:iCV00dYMe9hNV9oEyoa0VfCy/a9evgfey9FV1RG/5r...
# 30032921  [[6:iCV00dYMe9hNV9oEyoa0VfCy/a9evgfey9FV1RG/5r...
# 30789201  [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# 31293419  [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# 33566344  [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# 33818432  [[6:iCV00dYMe9hNV9oEyoa0VfCy/a9evgfey9FV1RG/5r...
# 35079741  [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# 35332519  [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# 37602330  [[6:iCV00dYMe9hNV9oEyoa0VfCy/a9evgfey9FV1RG/5r...
# 38107271  [[6:iCV00dYMe9hNV9oEyoa0VfCy/a9evgfey9FV1RG/5r...
# 38612349  [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V1V1V1X...
# 38864522  [[6:iCV00dYMe9hNV9oEyoa0VfCy/a9evgfey9FV1RG/5r...
# 42650314  [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V1V1V1X...
# 42902529  [[6:iCV00dYMe9hNV9oEyoa0VfCy/a9evgfey9FV1RG/5r...
# 43912103  [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# 45679327  [[6:iCV00dYMe9hNV9oEyoa0VfCy/a9evgfey9FV1RG/5r...
# 45931170  [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...
# 48954357  [[3:11QQoW503vV1V1cdcV1V1V1V1V1V1V1V1V1V133FfX...

# %%
big_dict_smb[512421] #KeyError

for k,v in big_dict_smb.items():
    if 512421 in v:
        print(k)
        break
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-288-923afa11c3dc> in <module>
# ----> 1 big_dict_smb[512421]
#
# KeyError: 512421

# %%
case2_diagram = df2_smb.loc[list(set(big_dict_smb[10]))]
time_lists = case2_diagram.session_time_list.tolist()
time_lists = [list(x) for x in time_lists]
ips = case2_diagram.ip_src.tolist()
countries = case2_diagram.country.tolist()
print(len(set(countries)),len(set(ips)))
# pickle_dir = '/home/antslab/spark_data/pcap_inter/2020_01_10/中華電信/case_pickles/'
pickle.dump(obj=(time_lists,ips,countries),file=open(pickle_dir+'case#2_threetuples.pkl','wb'))
# Out:
# 141 9056

# %% [markdown]
# #### Functionize

# %%
 
def prepare_df(df2,protocol_name):
    protocol_name = str(protocol_name).lower()
    '''
    df2: filterout no payload's all sessions df
    protocol_name: what TCP protocol string would be contained e.g., smb,http,tds...
    
    return1: protocol original dataframe (session-based)
    return2: protocol payload dataframe (packet-based)
    '''
    def sort_fn(data):
        '''
        sort by time: itemgetter(1)
        sort by size: itemgetter(2)
        '''
        return sorted(data,key=itemgetter(2))
    def split_col_len(session):
        '''
        input: list(session) of lists(packets) =>tuple=(hash,time)

        Return1: list of ssdeep length
        Return2: list of session's packets hashes
        '''
    #     for session in payload_li:
#         packet_payload = []
        packet_len = []
        for packet in session:
            ssdeep_hash = packet[0]
    #         packet_payload.append(ssdeep_hash)
            packet_len.append(ssdeep_hash.split(':')[0])
        return packet_len#,packet_payload

    def split_col_hash(session):
        '''
        input: list(session) of lists(packets) =>tuple=(hash,time)

        Return1: list of ssdeep length
        Return2: list of session's packets hashes
        '''
    #     for session in payload_li:
        packet_payload = []
#         packet_len = []
        for packet in session:
            ssdeep_hash = packet[0]
            packet_payload.append(ssdeep_hash)
    #         packet_len.append(ssdeep_hash.split(':')[0])
        return packet_payload

    df2_protocol = df2[(df2.frame_i_max_protocols.str.contains(protocol_name))&(df2.frame_o_max_protocols.str.contains(protocol_name))]
    df2_protocol_payload = df2_protocol[['tcp_i_payload_list']]
    df2_protocol_payload['tcp_i_payload_list'] = df2_protocol_payload.tcp_i_payload_list.map(sort_fn)
    df2_protocol_payload['size'] = df2_protocol_payload.tcp_i_payload_list.map(split_col_len) #,df2_protocol_payload['hash']
    df2_protocol_payload['hash'] = df2_protocol_payload.tcp_i_payload_list.map(split_col_hash)
    L_size = [x if isinstance(x, list) else [x] for x in df2_protocol_payload['size']]
    L_hash = [x if isinstance(x, list) else [x] for x in df2_protocol_payload['hash']]
    df2_protocol_payload = pd.DataFrame({
        'idx':df2_protocol_payload.index.values.repeat([len(x) for x in L_size]),
        'size':list(chain.from_iterable(L_size)),
        'hash':list(chain.from_iterable(L_hash))
        })
    # df2_protocol_payload['idx'] = 
    df2_protocol_payload['size'] = df2_protocol_payload['size'].astype(int)
    return df2_protocol, df2_protocol_payload

# %%
def similarity_compare(df2_protocol,df2_protocol_payload,thr=0,thr2=10): #40
    '''
    GOAL: compare with timestamp's q1,q2,q3 to similar size packet. Pick max value for score.
    df2_protocol: protocol original dataframe (session-based)
    df2_protocol_payload: protocol payload dataframe (packet-based)
    
    Return: dictionary with each cluster 
    '''
    def ssdeep_compare(target_hash,candidate_df):
        '''
        Input1: string of hash
        Input2: dataframe of candidate
        '''
        def compare(candidate_hash):
            return ssdeep.compare(target_hash,candidate_hash)
        return candidate_df.hash.map(compare)
    big_dict_protocol = {}
#     big_dict_protocol2 = {} #test
    used_idx_li = []
    for idx in tqdm(df2_protocol.index):
        if idx in used_idx_li:
            continue
        target = df2_protocol_payload[df2_protocol_payload.idx == idx]
        target = target.reset_index(drop=True)
        t_len = len(target)
        q1 = int(t_len*0.25)
        q2 = int(t_len*0.5)
        t_q1 = target.iloc[q1,-1]
        candidate = df2_protocol_payload[df2_protocol_payload.idx>idx]
        candidate = candidate[~candidate.idx.isin(used_idx_li)]
        candidate['idx'] = candidate.idx.astype(str)
        candidate_q1 = candidate[candidate['size']==target.iloc[q1,-2]]
        candidate['q1'] = ssdeep_compare(t_q1,candidate_q1)
        if q2 != q1:
            t_q2 = target.iloc[q2,-1]
            q3 = int(t_len*0.75)
            candidate_q2 = candidate[candidate['size']==target.iloc[q2,-2]]
            candidate['q2'] = ssdeep_compare(t_q2,candidate_q2)
            if q3 != q2:
                t_q3 = target.iloc[q3,-1]
                candidate_q3 = candidate[candidate['size']==target.iloc[q3,-2]]
                candidate['q3'] = ssdeep_compare(t_q3,candidate_q3)
        candidate = candidate.drop(['size','hash'],axis=1)
        candidate['score'] = candidate.max(axis=1)
        candidate = candidate[candidate.score>thr] #相似度分數，數字越小速度愈快、數字越大越多群
        candidate['idx'] = candidate.idx.astype(int)
#         candidate2 = candidate[candidate.score<thr2] #test
        idx_li = list(set(candidate.idx.tolist()))
#         idx_li2 = list(set(candidate2.idx.tolist())) #test
        if len(idx_li)>0:
            big_dict_protocol[idx] = idx_li
            used_idx_li.extend(idx_li)
#         if len(idx_li2)>0: #test
#             big_dict_protocol2[idx] = idx_li2 # test
    return big_dict_protocol#,big_dict_protocol2 #test

# %% [markdown]
# * 改成pool

# %%
# def similarity_compare_mu(df2_protocol,df2_protocol_payload,thr=40,nprocs=12):
#     '''
#     GOAL: Multi-preocessing a function.
#     df2_protocol: protocol original dataframe (session-based)
#     df2_protocol_payload: protocol payload dataframe (packet-based)
    
#     Return: dictionary with each cluster 
#     '''
#     def ssdeep_compare(target_hash,candidate_df):
#         '''
#         Input1: string of hash
#         Input2: dataframe of candidate
#         '''
#         def compare(candidate_hash):
#             return ssdeep.compare(target_hash,candidate_hash)
#         return candidate_df.hash.map(compare)
# #     big_dict_protocol = {}
# #     for idx in tqdm(df2_protocol.index):
# #         if idx in used_idx_li:
# #             continue
        
#     def main_compare(idx,out_q):
#         big_dict_protocol = {}
#         target = df2_protocol_payload[df2_protocol_payload.idx == idx]
#         target = target.reset_index(drop=True)
#         t_len = len(target)
#         q1 = int(t_len*0.25)
#         q2 = int(t_len*0.5)
#         t_q1 = target.iloc[q1,-1]
#         candidate = df2_protocol_payload[df2_protocol_payload.idx>idx]
#         candidate['idx'] = candidate.idx.astype(str)
#         candidate_q1 = candidate[candidate['size']==target.iloc[q1,-2]]
#         candidate['q1'] = ssdeep_compare(t_q1,candidate_q1)
#         if q2 != q1:
#             t_q2 = target.iloc[q2,-1]
#             q3 = int(t_len*0.75)
#             candidate_q2 = candidate[candidate['size']==target.iloc[q2,-2]]
#             candidate['q2'] = ssdeep_compare(t_q2,candidate_q2)
#             if q3 != q2:
#                 t_q3 = target.iloc[q3,-1]
#                 candidate_q3 = candidate[candidate['size']==target.iloc[q3,-2]]
#                 candidate['q3'] = ssdeep_compare(t_q3,candidate_q3)
#         candidate = candidate.drop(['size','hash'],axis=1)
#         candidate['score'] = candidate.max(axis=1)
#         candidate = candidate[candidate.score>=thr] #相似度分數，數字越小速度愈快、數字越大越多群
#         candidate['idx'] = candidate.idx.astype(int)
#         idx_li = candidate.idx.tolist()
#         if len(idx_li)>0:
#             big_dict_protocol[idx] = idx_li
# #             used_idx_li.extend(idx_li)
# #             used_idx_li = list(set(used_idx_li))
#         out_q.put(big_dict_protocol)#return big_dict_protocol
# #     with Manager() as manager:
# #     used_idx_li = manager.list()
#     out_q = mp.Queue()
    
# #         big_dict_protocol = manager.dict()
#     procs = []
#     idx_li = df2_protocol.index.tolist()
#     chunksize = int(math.ceil(len(idx_li) / float(nprocs)))
# #     for idx in df2_protocol.index:
        
#     for i in range(nprocs):
#         p = mp.Process(target=main_compare,args=(idx_li[chunksize*i:chunksize*(i+1)],out_q))
#         procs.append(p)
#         p.start()
# #     for idx in tqdm(df2_protocol.index):
# #         if idx in used_idx_li:
# #             continue
# #         p = Process(target=main_compare, args=(used_idx_li,idx,big_dict_protocol))
# #         p.start()
# #         time.sleep(0.5)
# #         processes.append(p)
#     resultdict = {}    
#     for i in range(nprocs):
#         resultdict.update(out_q.get())
#     for p in procs:
# #         time.sleep(0.5)
#         p.join()
#     return resultdict#big_dict_protocol

# %%
def find_cluster(big_dict,idx):
    '''
    big_dict: big_dict_protocol
    idx: which idx want to find
    Return cluster id (big_dict"s key number')
    '''
    idx = int(idx)
    try:
        big_dict[idx] #KeyError
        return idx
    except KeyError:
        for k,v in big_dict.items():
            if idx in v:
                return k
                break

# %%
def write2pkl(df2_protocol,big_dict,cluster_key,case_id):
    '''
    GOAL: output 3-tuple to draw time diagram
    df2_protocol: original dataframe session-based
    big_dict: big_dict_protocol
    cluster_key: print by find_cluster function
    case_id: user defined to identify
    '''
    cluster_key = int(cluster_key)
#     print(big_dict[cluster_key])
    temp_li = big_dict[cluster_key][:]
#     print(temp_li)
    temp_li.append(cluster_key)
#     print(temp_li)
#     temp_li = temp_li2[:]
    case_diagram = df2_protocol.loc[list(set(temp_li))]
    time_lists = case_diagram.session_time_list.tolist()
    time_lists = [list(x) for x in time_lists]
    ips = case_diagram.ip_src.tolist()
    countries = case_diagram.country.tolist()
    print('Unique Country#:',len(set(countries)),"Unique IP#:",len(set(ips)),'Session#:',len(time_lists))
    # pickle_dir = '/home/antslab/spark_data/pcap_inter/2020_01_10/中華電信/case_pickles/'
    pickle.dump(obj=(time_lists,ips,countries),file=open(pickle_dir+'case#'+str(case_id)+'_threetuples.pkl','wb'))

# %%
telnet_df, telnet_df_payload = prepare_df(df2,'telnet')
telnet_big_dict = similarity_compare(telnet_df,telnet_df_payload)
len(telnet_big_dict.keys())

# %%
cluster_stat(telnet_big_dict,telnet_df)
# Out:
# 原本總共sessions#: 445
# 共有#sessions可分群: 439 共有#lonerSessions: 6
# 可分為#群: 13
# 前三大的cluster key與對應之群集大小
#  63374     110
# 158785    100
# 557382     96
# 661586     26
# 934384     26
# Name: 0, dtype: int64
#                 0
# count   13.000000
# mean    33.769231
# std     39.875126
# min      2.000000
# 25%     10.000000
# 50%     15.000000
# 75%     26.000000
# max    110.000000

# %%
write2pkl(telnet_df,telnet_big_dict,63374,"telnet_1")
write2pkl(telnet_df,telnet_big_dict,158785,"telnet_2")
write2pkl(telnet_df,telnet_big_dict,557382,"telnet_3")
# Out:
# Unique Country#: 2 Unique IP#: 3 Session#: 110
# Unique Country#: 1 Unique IP#: 2 Session#: 100
# Unique Country#: 1 Unique IP#: 2 Session#: 96

# %%
telnet_df[telnet_df.ip_src == '184.154.47.2']
# Out:
#           session_time                                  session_time_list  \
# 4323967   1.578657e+09  [1578656838.646141, 1578656838.646389, 1578656...
# 6089291   1.578657e+09  [1578656859.986416, 1578656859.986725, 1578656...
# 6592952   1.578636e+09  [1578636262.320167, 1578636263.319424, 1578636...
# 8863854   1.578657e+09  [1578656831.159723, 1578656832.15703, 15786568...
# 9116585   1.578646e+09  [1578645820.728886, 1578645821.727919, 1578645...
# 22241687  1.578646e+09  [1578645813.079108, 1578645813.079411, 1578645...
# 30568753  1.578636e+09  [1578636288.475206, 1578636288.475441, 1578636...
# 33093485  1.578657e+09  [1578656866.721283, 1578656866.721576, 1578656...
# 33345857  1.578646e+09  [1578645836.445296, 1578645836.445623, 1578645...
# 43187420  1.578646e+09  [1578645853.380317, 1578645854.379606, 1578645...
#
#           session_duration  session_tt_packet  session_i_tt_packet  \
# 4323967          15.580751                 14                    9
# 6089291          10.429977                  9                    5
# 6592952          17.556145                 15                   10
# 8863854          14.985957                 15                   10
# 9116585          16.753340                 11                    7
# 22241687         15.845175                  9                    5
# 30568753         12.050930                  9                    5
# 33093485         11.759487                  9                    5
# 33345857         14.141236                 13                    8
# 43187420         20.399635                 19                   13
#
#           session_o_tt_packet  session_tt_frame_length  \
# 4323967                     5                     1543
# 6089291                     4                      784
# 6592952                     5                     1853
# 8863854                     5                     1853
# 9116585                     4                     1055
# 22241687                    4                      829
# 30568753                    4                      784
# 33093485                    4                      673
# 33345857                    5                     1374
# 43187420                    6                     1609
#
#           session_i_tt_frame_length  session_o_tt_frame_length  udp_tt_length  \
# 4323967                      1170.0                      373.0            NaN
# 6089291                       485.0                      299.0            NaN
# 6592952                      1480.0                      373.0            NaN
# 8863854                      1480.0                      373.0            NaN
# 9116585                       756.0                      299.0            NaN
# 22241687                      530.0                      299.0            NaN
# 30568753                      485.0                      299.0            NaN
# 33093485                      374.0                      299.0            NaN
# 33345857                     1001.0                      373.0            NaN
# 43187420                     1150.0                      459.0            NaN
#
#           udp_i_tt_length  udp_o_tt_length  udp_i_avg_length  \
# 4323967               NaN              NaN               NaN
# 6089291               NaN              NaN               NaN
# 6592952               NaN              NaN               NaN
# 8863854               NaN              NaN               NaN
# 9116585               NaN              NaN               NaN
# 22241687              NaN              NaN               NaN
# 30568753              NaN              NaN               NaN
# 33093485              NaN              NaN               NaN
# 33345857              NaN              NaN               NaN
# 43187420              NaN              NaN               NaN
#
#           udp_o_avg_length  icmp_i_avg_length  icmp_o_avg_length  \
# 4323967                NaN                NaN                NaN
# 6089291                NaN                NaN                NaN
# 6592952                NaN                NaN                NaN
# 8863854                NaN                NaN                NaN
# 9116585                NaN                NaN                NaN
# 22241687               NaN                NaN                NaN
# 30568753               NaN                NaN                NaN
# 33093485               NaN                NaN                NaN
# 33345857               NaN                NaN                NaN
# 43187420               NaN                NaN                NaN
#
#           icmp_tt_original_datagram_length  icmp_i_tt_datagram_length  \
# 4323967                                NaN                        NaN
# 6089291                                NaN                        NaN
# 6592952                                NaN                        NaN
# 8863854                                NaN                        NaN
# 9116585                                NaN                        NaN
# 22241687                               NaN                        NaN
# 30568753                               NaN                        NaN
# 33093485                               NaN                        NaN
# 33345857                               NaN                        NaN
# 43187420                               NaN                        NaN
#
#           icmp_o_tt_datagram_length  icmp_i_avg_datagram_length  \
# 4323967                         NaN                         NaN
# 6089291                         NaN                         NaN
# 6592952                         NaN                         NaN
# 8863854                         NaN                         NaN
# 9116585                         NaN                         NaN
# 22241687                        NaN                         NaN
# 30568753                        NaN                         NaN
# 33093485                        NaN                         NaN
# 33345857                        NaN                         NaN
# 43187420                        NaN                         NaN
#
#           icmp_o_avg_datagram_length  tcp_tt_payload_length  \
# 4323967                          NaN                  607.0
# 6089291                          NaN                  186.0
# 6592952                          NaN                  843.0
# 8863854                          NaN                  843.0
# 9116585                          NaN                  317.0
# 22241687                         NaN                  231.0
# 30568753                         NaN                  186.0
# 33093485                         NaN                   75.0
# 33345857                         NaN                  504.0
# 43187420                         NaN                  315.0
#
#           tcp_i_tt_payload_length  tcp_o_tt_payload_length  \
# 4323967                     580.0                     27.0
# 6089291                     159.0                     27.0
# 6592952                     816.0                     27.0
# 8863854                     816.0                     27.0
# 9116585                     290.0                     27.0
# 22241687                    204.0                     27.0
# 30568753                    159.0                     27.0
# 33093485                     48.0                     27.0
# 33345857                    477.0                     27.0
# 43187420                    288.0                     27.0
#
#           tcp_i_avg_payload_length  tcp_o_avg_payload_length        ip_src  \
# 4323967                  64.444444                      5.40  184.154.47.2
# 6089291                  31.800000                      6.75  184.154.47.2
# 6592952                  81.600000                      5.40  184.154.47.2
# 8863854                  81.600000                      5.40  184.154.47.2
# 9116585                  41.428571                      6.75  184.154.47.2
# 22241687                 40.800000                      6.75  184.154.47.2
# 30568753                 31.800000                      6.75  184.154.47.2
# 33093485                  9.600000                      6.75  184.154.47.2
# 33345857                 59.625000                      5.40  184.154.47.2
# 43187420                 22.153846                      4.50  184.154.47.2
#
#                   ip_dst  tcp_srcport  tcp_dstport  udp_srcport  udp_dstport  \
# 4323967   210.242.148.22      60274.0         23.0          NaN          NaN
# 6089291   210.242.148.22      34096.0         23.0          NaN          NaN
# 6592952   210.242.148.18      53990.0         23.0          NaN          NaN
# 8863854   210.242.148.22      50922.0         23.0          NaN          NaN
# 9116585   210.242.149.17      43548.0         23.0          NaN          NaN
# 22241687  210.242.149.17      34296.0         23.0          NaN          NaN
# 30568753  210.242.148.18      49816.0         23.0          NaN          NaN
# 33093485  210.242.148.22      50195.0         23.0          NaN          NaN
# 33345857  210.242.149.17      33199.0         23.0          NaN          NaN
# 43187420  210.242.149.17      39273.0         23.0          NaN          NaN
#
#                 country   city subdivisions         domain  \
# 4323967   United States  Milan     Illinois  singlehop.net
# 6089291   United States  Milan     Illinois  singlehop.net
# 6592952   United States  Milan     Illinois  singlehop.net
# 8863854   United States  Milan     Illinois  singlehop.net
# 9116585   United States  Milan     Illinois  singlehop.net
# 22241687  United States  Milan     Illinois  singlehop.net
# 30568753  United States  Milan     Illinois  singlehop.net
# 33093485  United States  Milan     Illinois  singlehop.net
# 33345857  United States  Milan     Illinois  singlehop.net
# 43187420  United States  Milan     Illinois  singlehop.net
#
#          frame_i_common_protocols frame_o_common_protocols  \
# 4323967      eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 6089291      eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 6592952      eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 8863854      eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 9116585      eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 22241687     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 30568753     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 33093485     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 33345857     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 43187420     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
#
#                 frame_i_max_protocols        frame_o_max_protocols  \
# 4323967   eth:ethertype:ip:tcp:telnet  eth:ethertype:ip:tcp:telnet
# 6089291   eth:ethertype:ip:tcp:telnet  eth:ethertype:ip:tcp:telnet
# 6592952   eth:ethertype:ip:tcp:telnet  eth:ethertype:ip:tcp:telnet
# 8863854   eth:ethertype:ip:tcp:telnet  eth:ethertype:ip:tcp:telnet
# 9116585   eth:ethertype:ip:tcp:telnet  eth:ethertype:ip:tcp:telnet
# 22241687  eth:ethertype:ip:tcp:telnet  eth:ethertype:ip:tcp:telnet
# 30568753  eth:ethertype:ip:tcp:telnet  eth:ethertype:ip:tcp:telnet
# 33093485  eth:ethertype:ip:tcp:telnet  eth:ethertype:ip:tcp:telnet
# 33345857  eth:ethertype:ip:tcp:telnet  eth:ethertype:ip:tcp:telnet
# 43187420  eth:ethertype:ip:tcp:telnet  eth:ethertype:ip:tcp:telnet
#
#                                          tcp_i_payload_list  \
# 4323967   [[6:KvVhWKnfANAIKIZVyfOMDiZce5C/jcwV1OkYVoMRo5...
# 6089291   [[12:YnT4FLBIhvcKC/gkyVF9ekV9A05fxquQCh+nYM:sT...
# 6592952   [[12:rHXq6xmMRe48Is0+R56Y1awh5UP+/4D7eiMJNkZr1...
# 8863854   [[12:rHXq6xmMRetkIs0+R56Y1awh5UP+/4D7eiMJNkZr1...
# 9116585   [[12:Ynf852ccEKC/gkOkOoMReT2VmF9eqSz0uP4:wccEX...
# 22241687  [[12:rHXq6xmMReT2klIs0+R56Y1awh5UP+/4D7eiMJNkZ...
# 30568753  [[12:YnT9fEfQ+i51JEKC/gkyVF9ekV9A05fxquQCh+nYM...
# 33093485  [[3:PX6gX9/B91XV1UV9KNg/wV1aV1avRVz9F/Vk+fV1Bu...
# 33345857  [[12:YnT9iP6BHccKC/gkyVF9ekV9A05fxquQCh+nYM:sT...
# 43187420  [[3:PX6gX9/B91XV1UV9KNg/wV1aV1avRVz9F/Vk+fV1Bu...
#
#                                          tcp_o_payload_list
# 4323967   [[3:UNT2CIQ7A4fTxx18uZhEn:UgNIrfdxSiEn, 157865...
# 6089291   [[3:UNT2CIQ7A4fTxx18uZhEn:UgNIrfdxSiEn, 157865...
# 6592952   [[3:UNT2CIQ7A4fTxx18uZhEn:UgNIrfdxSiEn, 157863...
# 8863854   [[3:UNT2CIQ7A4fTxx18uZhEn:UgNIrfdxSiEn, 157865...
# 9116585   [[3:UNT2CIQ7A4fTxx18uZhEn:UgNIrfdxSiEn, 157864...
# 22241687  [[3:UNT2CIQ7A4fTxx18uZhEn:UgNIrfdxSiEn, 157864...
# 30568753  [[3:UNT2CIQ7A4fTxx18uZhEn:UgNIrfdxSiEn, 157863...
# 33093485  [[3:UNT2CIQ7A4fTxx18uZhEn:UgNIrfdxSiEn, 157865...
# 33345857  [[3:UNT2CIQ7A4fTxx18uZhEn:UgNIrfdxSiEn, 157864...
# 43187420  [[3:UNT2CIQ7A4fTxx18uZhEn:UgNIrfdxSiEn, 157864...

# %%
find_cluster(telnet_big_dict,43187420)
# Out:
# 32297542

# %%
write2pkl(telnet_df,telnet_big_dict,32297542,3)
# Out:
# 2 2

# %% [markdown]
# #### tds

# %%
tds_df, tds_df_payload = prepare_df(df2,'tds')
tds_big_dict = similarity_compare(tds_df,tds_df_payload)
len(tds_big_dict.keys()) #10:03:06
# Out:
#  68%|██████▊   | 1231823/1799699 [4:38:47<3:04:02, 51.43it/s] IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
#  77%|███████▋  | 1381273/1799699 [5:11:27<1:16:11, 91.52it/s] IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
#  85%|████████▍ | 1521053/1799699 [5:42:50<1:24:30, 54.96it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
#  93%|█████████▎| 1679939/1799699 [6:15:11<34:39, 57.59it/s] IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
cluster_stat(tds_big_dict,tds_df)
# Out:
# 原本總共sessions#: 1799699
# 共有#sessions可分群: 1799692 共有#lonerSessions: 7
# 可分為#群: 68
# 前三大的cluster key與對應之群集大小
#  677      800831
# 664      397886
# 4502     250370
# 6583      61058
# 10367     56857
# Name: 0, dtype: int64
#                    0
# count      68.000000
# mean    26466.058824
# std    111104.539480
# min         2.000000
# 25%        27.000000
# 50%       188.500000
# 75%      4416.000000
# max    800831.000000

# %%
write2pkl(tds_df,tds_big_dict,677,"tds_1")
write2pkl(tds_df,tds_big_dict,664,"tds_2")
write2pkl(tds_df,tds_big_dict,4502,"tds_3")
# Out:
# Unique Country#: 25 Unique IP#: 80 Session#: 800831
# Unique Country#: 89 Unique IP#: 972 Session#: 397886
# Unique Country#: 28 Unique IP#: 85 Session#: 250370

# %%
tds_df[tds_df.ip_src == '116.98.142.146']
# Out:
#           session_time                                  session_time_list  \
# 8880      1.578652e+09  [1578652258.789153, 1578652258.7894, 157865225...
# 8893      1.578651e+09  [1578650551.93434, 1578650551.934552, 15786505...
# 8950      1.578648e+09  [1578647726.148316, 1578647726.148473, 1578647...
# 8956      1.578651e+09  [1578651049.900827, 1578651049.901286, 1578651...
# 8959      1.578648e+09  [1578647865.141733, 1578647865.142038, 1578647...
# ...                ...                                                ...
# 50218448  1.578653e+09  [1578652838.658343, 1578652838.658545, 1578652...
# 50218459  1.578653e+09  [1578652571.62375, 1578652571.623942, 15786525...
# 50218461  1.578652e+09  [1578651530.773362, 1578651530.773515, 1578651...
# 50218488  1.578652e+09  [1578651758.386984, 1578651758.387154, 1578651...
# 50218494  1.578649e+09  [1578649199.295716, 1578649199.295893, 1578649...
#
#           session_duration  session_tt_packet  session_i_tt_packet  \
# 8880              1.208934                  8                    5
# 8893              0.576697                  8                    5
# 8950              1.452684                 10                    6
# 8956             93.001999                 14                    8
# 8959              0.592815                 10                    6
# ...                    ...                ...                  ...
# 50218448          0.670841                  8                    5
# 50218459        149.046448                 22                   11
# 50218461          0.659094                 12                    6
# 50218488          0.975799                  8                    5
# 50218494          3.943994                  8                    5
#
#           session_o_tt_packet  session_tt_frame_length  \
# 8880                        3                      732
# 8893                        3                      730
# 8950                        4                      924
# 8956                        6                     1280
# 8959                        4                      922
# ...                       ...                      ...
# 50218448                    3                      724
# 50218459                   11                     1907
# 50218461                    6                     1041
# 50218488                    3                      730
# 50218494                    3                      730
#
#           session_i_tt_frame_length  session_o_tt_frame_length  udp_tt_length  \
# 8880                          478.0                      254.0            NaN
# 8893                          476.0                      254.0            NaN
# 8950                          542.0                      382.0            NaN
# 8956                          840.0                      440.0            NaN
# 8959                          540.0                      382.0            NaN
# ...                             ...                        ...            ...
# 50218448                      476.0                      248.0            NaN
# 50218459                     1062.0                      845.0            NaN
# 50218461                      570.0                      471.0            NaN
# 50218488                      476.0                      254.0            NaN
# 50218494                      476.0                      254.0            NaN
#
#           udp_i_tt_length  udp_o_tt_length  udp_i_avg_length  \
# 8880                  NaN              NaN               NaN
# 8893                  NaN              NaN               NaN
# 8950                  NaN              NaN               NaN
# 8956                  NaN              NaN               NaN
# 8959                  NaN              NaN               NaN
# ...                   ...              ...               ...
# 50218448              NaN              NaN               NaN
# 50218459              NaN              NaN               NaN
# 50218461              NaN              NaN               NaN
# 50218488              NaN              NaN               NaN
# 50218494              NaN              NaN               NaN
#
#           udp_o_avg_length  icmp_i_avg_length  icmp_o_avg_length  \
# 8880                   NaN                NaN                NaN
# 8893                   NaN                NaN                NaN
# 8950                   NaN                NaN                NaN
# 8956                   NaN                NaN                NaN
# 8959                   NaN                NaN                NaN
# ...                    ...                ...                ...
# 50218448               NaN                NaN                NaN
# 50218459               NaN                NaN                NaN
# 50218461               NaN                NaN                NaN
# 50218488               NaN                NaN                NaN
# 50218494               NaN                NaN                NaN
#
#           icmp_tt_original_datagram_length  icmp_i_tt_datagram_length  \
# 8880                                   NaN                        NaN
# 8893                                   NaN                        NaN
# 8950                                   NaN                        NaN
# 8956                                   NaN                        NaN
# 8959                                   NaN                        NaN
# ...                                    ...                        ...
# 50218448                               NaN                        NaN
# 50218459                               NaN                        NaN
# 50218461                               NaN                        NaN
# 50218488                               NaN                        NaN
# 50218494                               NaN                        NaN
#
#           icmp_o_tt_datagram_length  icmp_i_avg_datagram_length  \
# 8880                            NaN                         NaN
# 8893                            NaN                         NaN
# 8950                            NaN                         NaN
# 8956                            NaN                         NaN
# 8959                            NaN                         NaN
# ...                             ...                         ...
# 50218448                        NaN                         NaN
# 50218459                        NaN                         NaN
# 50218461                        NaN                         NaN
# 50218488                        NaN                         NaN
# 50218494                        NaN                         NaN
#
#           icmp_o_avg_datagram_length  tcp_tt_payload_length  \
# 8880                             NaN                  270.0
# 8893                             NaN                  268.0
# 8950                             NaN                  342.0
# 8956                             NaN                  458.0
# 8959                             NaN                  340.0
# ...                              ...                    ...
# 50218448                         NaN                  268.0
# 50218459                         NaN                  623.0
# 50218461                         NaN                  351.0
# 50218488                         NaN                  268.0
# 50218494                         NaN                  268.0
#
#           tcp_i_tt_payload_length  tcp_o_tt_payload_length  \
# 8880                        196.0                     74.0
# 8893                        194.0                     74.0
# 8950                        194.0                    148.0
# 8956                        384.0                     74.0
# 8959                        192.0                    148.0
# ...                           ...                      ...
# 50218448                    194.0                     74.0
# 50218459                    432.0                    191.0
# 50218461                    234.0                    117.0
# 50218488                    194.0                     74.0
# 50218494                    194.0                     74.0
#
#           tcp_i_avg_payload_length  tcp_o_avg_payload_length          ip_src  \
# 8880                     39.200000                 24.666667  116.98.142.146
# 8893                     38.800000                 24.666667  116.98.142.146
# 8950                     32.333333                 37.000000  116.98.142.146
# 8956                     48.000000                 12.333333  116.98.142.146
# 8959                     32.000000                 37.000000  116.98.142.146
# ...                            ...                       ...             ...
# 50218448                 38.800000                 24.666667  116.98.142.146
# 50218459                 39.272727                 17.363636  116.98.142.146
# 50218461                 39.000000                 19.500000  116.98.142.146
# 50218488                 38.800000                 24.666667  116.98.142.146
# 50218494                 38.800000                 24.666667  116.98.142.146
#
#                    ip_dst  tcp_srcport  tcp_dstport  udp_srcport  udp_dstport  \
# 8880      210.242.145.125      39341.0       1433.0          NaN          NaN
# 8893       210.242.145.65      33691.0       1433.0          NaN          NaN
# 8950       210.242.145.65      47653.0       1433.0          NaN          NaN
# 8956       210.242.145.65      48028.0       1433.0          NaN          NaN
# 8959       210.242.145.65      48704.0       1433.0          NaN          NaN
# ...                   ...          ...          ...          ...          ...
# 50218448  210.242.149.123      49321.0       1433.0          NaN          NaN
# 50218459  210.242.149.125      35061.0       1433.0          NaN          NaN
# 50218461  210.242.149.125      35456.0       1433.0          NaN          NaN
# 50218488  210.242.149.125      43974.0       1433.0          NaN          NaN
# 50218494  210.242.149.125      45568.0       1433.0          NaN          NaN
#
#           country        city         subdivisions      domain  \
# 8880      Vietnam  Quảng Ngãi  Quảng Ngãi Province  viettel.vn
# 8893      Vietnam  Quảng Ngãi  Quảng Ngãi Province  viettel.vn
# 8950      Vietnam  Quảng Ngãi  Quảng Ngãi Province  viettel.vn
# 8956      Vietnam  Quảng Ngãi  Quảng Ngãi Province  viettel.vn
# 8959      Vietnam  Quảng Ngãi  Quảng Ngãi Province  viettel.vn
# ...           ...         ...                  ...         ...
# 50218448  Vietnam  Quảng Ngãi  Quảng Ngãi Province  viettel.vn
# 50218459  Vietnam  Quảng Ngãi  Quảng Ngãi Province  viettel.vn
# 50218461  Vietnam  Quảng Ngãi  Quảng Ngãi Province  viettel.vn
# 50218488  Vietnam  Quảng Ngãi  Quảng Ngãi Province  viettel.vn
# 50218494  Vietnam  Quảng Ngãi  Quảng Ngãi Province  viettel.vn
#
#          frame_i_common_protocols frame_o_common_protocols  \
# 8880         eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 8893         eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 8950         eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 8956         eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 8959         eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# ...                           ...                      ...
# 50218448     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 50218459     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 50218461     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 50218488     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
# 50218494     eth:ethertype:ip:tcp     eth:ethertype:ip:tcp
#
#                      frame_i_max_protocols     frame_o_max_protocols  \
# 8880      eth:ethertype:ip:tcp:tds:gss-api  eth:ethertype:ip:tcp:tds
# 8893      eth:ethertype:ip:tcp:tds:gss-api  eth:ethertype:ip:tcp:tds
# 8950      eth:ethertype:ip:tcp:tds:gss-api  eth:ethertype:ip:tcp:tds
# 8956      eth:ethertype:ip:tcp:tds:gss-api  eth:ethertype:ip:tcp:tds
# 8959      eth:ethertype:ip:tcp:tds:gss-api  eth:ethertype:ip:tcp:tds
# ...                                    ...                       ...
# 50218448  eth:ethertype:ip:tcp:tds:gss-api  eth:ethertype:ip:tcp:tds
# 50218459  eth:ethertype:ip:tcp:tds:gss-api  eth:ethertype:ip:tcp:tds
# 50218461          eth:ethertype:ip:tcp:tds  eth:ethertype:ip:tcp:tds
# 50218488  eth:ethertype:ip:tcp:tds:gss-api  eth:ethertype:ip:tcp:tds
# 50218494  eth:ethertype:ip:tcp:tds:gss-api  eth:ethertype:ip:tcp:tds
#
#                                          tcp_i_payload_list  \
# 8880      [[12:M5YxTvuw3zLw7Ve9VgfY1QWxQtTVGgZA+Oi56imXJ...
# 8893      [[12:MdjYxTvuw3zLoyDV33uuEftajiA+Oi56iEvXJ:MC9...
# 8950      [[12:MdjYxTvuw3zLoy7xVZABVZeLpCZpCZp9sAPt3ppA+...
# 8956      [[12:M4YxTvuw36GmRpTuKZpVZAaE3YpyoyVfpA+Oi56iE...
# 8959      [[12:M4YxTvuw36GmRpJinvhtIJ1VNVQA+Oi56iEvXJ:M9...
# ...                                                     ...
# 50218448  [[12:MdjYxTvuw36I2OTApieK5xCVtpA+Oi5ac8VlJ:MC9...
# 50218459  [[12:M5YxTvuw3zLwLBU8fKE6saShEA+Oi5acmXJ:M29uw...
# 50218461  [[3:OfVGX4V9VfV1V1V1V1UQ91BVWfg0VZ39LfVbHfVYN1...
# 50218488  [[12:MdjYxTvuw36IH9aO/htGYYhtGaVVuV6JA+Oi5acmX...
# 50218494  [[12:MdjYxTvuw36IgUyV0SEtBEO++/A+Oi5acmXJ:MC9u...
#
#                                          tcp_o_payload_list
# 8880      [[6:Sf/U/93+uST5O3S3QWi2VfaSCI9uMQy6sd:s/U/B+u...
# 8893      [[6:Sf/U/93+uST5O3S3QWi2VfaSCI9uMQy6sd:s/U/B+u...
# 8950      [[6:Sf/U/93+uST5O3S3QWi2VfaSCI9uMQy6sd:s/U/B+u...
# 8956      [[6:Sf/U/93+uST5O3S3QWi2VfaSCI9uMQy6sd:s/U/B+u...
# 8959      [[6:Sf/U/93+uST5O3S3QWi2VfaSCI9uMQy6sd:s/U/B+u...
# ...                                                     ...
# 50218448  [[6:Sf/U/93+uST5O3S3QWi2VfaSCI9uMQy6sd:s/U/B+u...
# 50218459  [[3:Sf/fX3fV1V1V1V1V1UEpVWfnGV2V53+DvVXeHVP/3:...
# 50218461  [[3:Sf/fX3fV1V1V1V1V1UEpVWfnGV2V53+DvVXeHVP/3:...
# 50218488  [[6:Sf/U/93+uST5O3S3QWi2VfaSCI9uMQy6sd:s/U/B+u...
# 50218494  [[6:Sf/U/93+uST5O3S3QWi2VfaSCI9uMQy6sd:s/U/B+u...
#
# [20462 rows x 42 columns]

# %%
key_ = find_cluster(tds_big_dict,50218448)
write2pkl(tds_df,tds_big_dict,key_,4)
# Out:
# Unique Country#: 35 Unique IP#: 177 Session#: 1335894

# %% [markdown]
# #### smtp

# %%
smtp_df, smtp_df_payload = prepare_df(df2,'smtp')
smtp_big_dict = similarity_compare(smtp_df,smtp_df_payload)
gc.collect()
# Out:
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100%|██████████| 13945/13945 [00:01<00:00, 8721.09it/s]
# 238

# %%
cluster_stat(smtp_big_dict,smtp_df)
# Out:
# 原本總共sessions#: 13945
# 共有#sessions可分群: 13897 共有#lonerSessions: 48
# 可分為#群: 29
# 前三大的cluster key與對應之群集大小
#  880       12007
# 462476      358
# 131327      315
# 134687      309
# 158784      152
# Name: 0, dtype: int64
#                   0
# count     29.000000
# mean     479.206897
# std     2219.281679
# min        2.000000
# 25%       11.000000
# 50%       23.000000
# 75%       71.000000
# max    12007.000000

# %%
write2pkl(smtp_df,smtp_big_dict,880,"smtp_1")
write2pkl(smtp_df,smtp_big_dict,462476,"smtp_2")
write2pkl(smtp_df,smtp_big_dict,131327,"smtp_3")
# Out:
# Unique Country#: 8 Unique IP#: 29 Session#: 12007
# Unique Country#: 1 Unique IP#: 1 Session#: 358
# Unique Country#: 10 Unique IP#: 31 Session#: 315

# %% [markdown]
# #### FTP

# %%
ftp_df, ftp_df_payload = prepare_df(df2,'ftp')
ftp_big_dict = similarity_compare(ftp_df,ftp_df_payload)
gc.collect()
# Out:
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100%|██████████| 6322/6322 [00:00<00:00, 9011.29it/s]
# 0

# %%
cluster_stat(ftp_big_dict,ftp_df)
# Out:
# 原本總共sessions#: 6322
# 共有#sessions可分群: 6317 共有#lonerSessions: 5
# 可分為#群: 36
# 前三大的cluster key與對應之群集大小
#  1091      1902
# 1190      1248
# 1527      1035
# 63379      817
# 134623     242
# Name: 0, dtype: int64
#                  0
# count    36.000000
# mean    175.472222
# std     413.800952
# min       2.000000
# 25%       6.000000
# 50%      19.000000
# 75%      52.750000
# max    1902.000000

# %%
write2pkl(ftp_df,ftp_big_dict,1091,"ftp_1")
write2pkl(ftp_df,ftp_big_dict,1190,"ftp_2")
write2pkl(ftp_df,ftp_big_dict,1527,"ftp_3")
# Out:
# Unique Country#: 8 Unique IP#: 14 Session#: 1902
# Unique Country#: 9 Unique IP#: 26 Session#: 1248
# Unique Country#: 8 Unique IP#: 128 Session#: 1035

# %% [markdown]
# ### sip

# %%
sip_df, sip_df_payload = prepare_df(df2,'sip')
sip_big_dict = similarity_compare(sip_df,sip_df_payload)
cluster_stat(sip_big_dict,sip_df)
# Out:
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100%|██████████| 425/425 [00:00<00:00, 23313.27it/s]
# 原本總共sessions#: 425
# 共有#sessions可分群: 424 共有#lonerSessions: 1
# 可分為#群: 3
# 前三大的cluster key與對應之群集大小
#  18841     301
# 131584     69
# 334787     54
# Name: 0, dtype: int64
#                 0
# count    3.000000
# mean   141.333333
# std    138.478639
# min     54.000000
# 25%     61.500000
# 50%     69.000000
# 75%    185.000000
# max    301.000000

# %%
write2pkl(sip_df,sip_big_dict,18841,"sip_1")
write2pkl(sip_df,sip_big_dict,131584,"sip_2")
write2pkl(sip_df,sip_big_dict,334787,"sip_3")
# Out:
# Unique Country#: 1 Unique IP#: 48 Session#: 301
# Unique Country#: 1 Unique IP#: 1 Session#: 69
# Unique Country#: 2 Unique IP#: 4 Session#: 54

# %% [markdown]
# #### Mysql

# %%
mysql_df, mysql_df_payload = prepare_df(df2,'mysql')
mysql_big_dict = similarity_compare(mysql_df,mysql_df_payload)
cluster_stat(mysql_big_dict,mysql_df)
# Out:
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/antslab/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 100%|██████████| 2855/2855 [00:00<00:00, 33296.92it/s]
# 原本總共sessions#: 2855
# 共有#sessions可分群: 2855 共有#lonerSessions: 0
# 可分為#群: 2
# 前三大的cluster key與對應之群集大小
#  133852    2599
# 370392     256
# Name: 0, dtype: int64
#                  0
# count     2.000000
# mean   1427.500000
# std    1656.751188
# min     256.000000
# 25%     841.750000
# 50%    1427.500000
# 75%    2013.250000
# max    2599.000000

# %%
write2pkl(mysql_df,mysql_big_dict,133852,"mysql_1")
write2pkl(mysql_df,mysql_big_dict,370392,"mysql_2")
# write2pkl(mysql_df,mysql_big_dict,370392,"mysql_3")
# Out:
# Unique Country#: 5 Unique IP#: 19 Session#: 2599
# Unique Country#: 1 Unique IP#: 2 Session#: 256

# %%
pickle.dump(obj=(http_big_dict,smb_big_dict,telnet_big_dict,tds_big_dict,smtp_big_dict,ftp_big_dict,
                 sip_big_dict,mysql_big_dict),file=open(pickle_dir+"allProtocol_case_dict.pkl",'wb'))

# %% [markdown]
# # Deprecated
# * old original function

# %%
def build_matrix(sessions_payload,idxes):
    '''
    sessions_payload: list of lists (hashes)
    idxes: list (corresponding Index)
    
    Return: dictionry=> key=idx,value=list of tuples (idx_compare,final_session_score)
    '''
    sessions_num = len(sessions_payload)
    assert  sessions_num == len(idxes)
    big_dict = {}
    all_scores = []
    for i,(packets_payload,idx) in tqdm(enumerate(zip(sessions_payload,idxes))):
        packets_num = len(packets_payload)
        q1 = int(packets_num/4)
        q2 = int(packets_num/2)
        q3 = int(packets_num*0.75)
        
        tryq1 = packets_payload[q1]
        tryq1_split = tryq1.split(':')
        q1len_segment = tryq1_split[0]
        q1len_payload = ":".join(tryq1_split[1:])        
        if q1 == q2 == q3:
            flag=False
        else:
            tryq2 = packets_payload[q2]
            tryq2_split = tryq2.split(':')
            q2len_segment = tryq2_split[0]
            q2len_payload = ":".join(tryq2_split[1:])
            
            tryq3 = packets_payload[q3]
            tryq3_split = tryq3.split(':')
            q3len_segment = tryq3_split[0]
            q3len_payload = ":".join(tryq3_split[1:])            
            flag = True

        final_li = []
        for j in range(sessions_num-i-1): #往下比
            idx_compare = j+i+1
            session_payload_compare = sessions_payload[idx_compare]
            session_score = []
            for packet_payload_compare in session_payload_compare: #packet_payload_compare == '6:rHKAqEDxghMRo5auSGy6A7WfXl3Nupfh/aEjmjmn:rHXq6xmMRe9SNYV3NkZr8m'                
                test_segment = packet_payload_compare.split(':')[0]
                if test_segment == q1len_segment:
                    scoreq1 = ssdeep.compare(tryq1,packet_payload_compare)
                else:
                    scoreq1 = 0
                if flag:
                    if test_segment == q2len_segment:
                        scoreq2 = ssdeep.compare(tryq2,packet_payload_compare)
                    else:
                        scoreq2 = 0
                    if test_segment == q3len_segment:
                        scoreq3 = ssdeep.compare(tryq3,packet_payload_compare)
                    else:
                        scoreq3 = 0
                    if scoreq1 == scoreq2 == scoreq3 <1:
                        min_packet = packets_payload[0]
                        max_packet = packets_payload[-1]
                        scoreMin = 0
                        scoreMax = 0
                        if min_packet.split(':')[0] == test_segment:
                            scoreMin = ssdeep.compare(min_packet,packet_payload_compare) #第一個時間得比較
                        if max_packet.split(':')[0] == test_segment:
                            scoreMax = ssdeep.compare(max_packet,packet_payload_compare) #最後一個時間得比較
                        session_score.append(max(scoreMin,scoreMax))
                        continue
                session_score.append(max(scoreq1,scoreq2,scoreq3))
            final_score = max(session_score)
            if final_score>0:
                final_li.append((idxes[idx_compare],final_score))
                all_scores.append(final_score) #統計用
        big_dict[idx] = final_li
    return big_dict,all_scores
#                 test_split = packet_payload_compare.split(':')
#                 test_segment = test_split[0]
#                 if

# %%
# %%time
def build_matrix_mu(sessions_payload,idxes):
    '''
    sessions_payload: list of lists (hashes)
    idxes: list (corresponding Index)
    
    Return: dictionry=> key=idx,value=list of tuples (idx_compare,final_session_score)
    '''
    sessions_num = len(sessions_payload)
    assert  sessions_num == len(idxes)
    inputs = [(i,x,y) for i,(x,y) in enumerate(zip(sessions_payload,idxes))]
    
    
#     all_scores = []
def func(param):#i,(packets_payload,idx) in tqdm(enumerate(zip(sessions_payload,idxes))):
    i,packets_payload,idx = param
    big_dict = {}
    packets_num = len(packets_payload)
    q1 = int(packets_num/4)
    q2 = int(packets_num/2)
    q3 = int(packets_num*0.75)

    tryq1 = packets_payload[q1]
    tryq1_split = tryq1.split(':')
    q1len_segment = tryq1_split[0]
    q1len_payload = ":".join(tryq1_split[1:])        
    if q1 == q2 == q3:
        flag=False
    else:
        tryq2 = packets_payload[q2]
        tryq2_split = tryq2.split(':')
        q2len_segment = tryq2_split[0]
        q2len_payload = ":".join(tryq2_split[1:])

        tryq3 = packets_payload[q3]
        tryq3_split = tryq3.split(':')
        q3len_segment = tryq3_split[0]
        q3len_payload = ":".join(tryq3_split[1:])            
        flag = True

    final_li = []
    for j in range(sessions_num-i-1): #往下比
        idx_compare = j+i+1
        session_payload_compare = sessions_payload[idx_compare]
        session_score = []
        for packet_payload_compare in session_payload_compare: #packet_payload_compare == '6:rHKAqEDxghMRo5auSGy6A7WfXl3Nupfh/aEjmjmn:rHXq6xmMRe9SNYV3NkZr8m'                
            test_segment = packet_payload_compare.split(':')[0]
            scoreq1 = scoreq2 = scoreq3 = 0
            if test_segment == q1len_segment:
                scoreq1 = ssdeep.compare(tryq1,packet_payload_compare)
#             else:
#                 scoreq1 = 0
            if flag:
#                 scoreq2 = 0
                if test_segment == q2len_segment:
                    scoreq2 = ssdeep.compare(tryq2,packet_payload_compare)
#                 else:
#                     scoreq2 = 0
#                 scoreq3 = 0
                if test_segment == q3len_segment:
                    scoreq3 = ssdeep.compare(tryq3,packet_payload_compare)
#                 else:
#                     scoreq3 = 0
                if scoreq1 == scoreq2 == scoreq3 <1:
                    min_packet = packets_payload[0]
                    max_packet = packets_payload[-1]
                    scoreMin = scoreMax = 0
#                     scoreMax = 0
                    if min_packet.split(':')[0] == test_segment:
                        scoreMin = ssdeep.compare(min_packet,packet_payload_compare) #第一個時間得比較
                    if max_packet.split(':')[0] == test_segment:
                        scoreMax = ssdeep.compare(max_packet,packet_payload_compare) #最後一個時間得比較
                    session_score.append(max(scoreMin,scoreMax))
                    continue
            session_score.append(max(scoreq1,scoreq2,scoreq3))
        final_score = max(session_score)
        if final_score>0:
            final_li.append((idxes[idx_compare],final_score))
#             all_scores.append(final_score) #統計用
    big_dict[idx] = final_li

#         pool = Pool()
inputs = [(i,x,y) for i,(x,y) in enumerate(zip(session_payload,df2_http.index))]
sessions_num = len(session_payload)
sessions_payload=session_payload
idxes = df2_http.index
pool = Pool()
start = time.time()
out_li = pool.map(func,inputs)
end = time.time()
# with mp.Manager() as manager:
#     big_dict = manager.dict()
#     with manager.Pool() as pool:
#         pool.map(func, inputs) #(sessions_num,i,sessions_payload,q1len_segment,tryq1,q2len_segment,tryq2,q3len_segment,
            #tryq3,packets_payload)
#     return big_dict#,all_scores

#5h 33min 29s
# Out:
# CPU times: user 17.3 s, sys: 19 s, total: 36.4 s
# Wall time: 5h 33min 29s
# Process ForkPoolWorker-45:
# Process ForkPoolWorker-46:
# Process ForkPoolWorker-43:
# Process ForkPoolWorker-38:
# Process ForkPoolWorker-37:
# Process ForkPoolWorker-47:
# Process ForkPoolWorker-42:
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-44:
# Process ForkPoolWorker-40:
# Process ForkPoolWorker-41:
# Process ForkPoolWorker-36:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):

# %%
for i in range(len(out_li)):
    if out_li[i] != None:
        print(out_li[i])

# %%
inputs = []
for i,(packets_payload,idx) in tqdm(enumerate(zip(session_payload,df2_http.index))):
    inputs.append((i,packets_payload,idx))
    for

# %%
big_dict
# Out:
# <DictProxy object, typeid 'dict' at 0x7f4c85590d50>

# %%
one,two = build_matrix_mu(session_payload,df2_http.index) #1.05~1.6
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-5bf178d902d9> in <module>
# ----> 1 one,two = build_matrix_mu(session_payload,df2_http.index) #1.05~1.6
#
# <ipython-input-77-7416b2331735> in build_matrix_mu(sessions_payload, idxes)
#      80         big_dict = manager.dict()
#      81         with manager.Pool() as pool:
# ---> 82             pool.map(func, inputs) #(sessions_num,i,sessions_payload,q1len_segment,tryq1,q2len_segment,tryq2,q3len_segment,
#      83             #tryq3,packets_payload)
#      84     return big_dict#,all_scores
#
# <string> in map(self, *args, **kwds)
#
# ~/anaconda3/lib/python3.7/multiprocessing/managers.py in _callmethod(self, methodname, args, kwds)
#     816             conn = self._tls.connection
#     817
# --> 818         conn.send((self._id, methodname, args, kwds))
#     819         kind, result = conn.recv()
#     820
#
# ~/anaconda3/lib/python3.7/multiprocessing/connection.py in send(self, obj)
#     204         self._check_closed()
#     205         self._check_writable()
# --> 206         self._send_bytes(_ForkingPickler.dumps(obj))
#     207
#     208     def recv_bytes(self, maxlength=None):
#
# ~/anaconda3/lib/python3.7/multiprocessing/reduction.py in dumps(cls, obj, protocol)
#      49     def dumps(cls, obj, protocol=None):
#      50         buf = io.BytesIO()
# ---> 51         cls(buf, protocol).dump(obj)
#      52         return buf.getbuffer()
#      53
#
# AttributeError: Can't pickle local object 'build_matrix_mu.<locals>.func'

# %%
max(0,0)
# Out:
# 0

# %%
session_payload[0]
# Out:
# ['6:rHKAqEDxghMRo5auSGy6A7WfXl3Nupfh/aEjmjmn:rHXq6xmMRe9SNYV3NkZr8m',
#  '6:rHKAqEDxghMRo5auSGy6A7WfXl3Nupfh/aEjmjmn:rHXq6xmMRe9SNYV3NkZr8m',
#  '6:rHKAqEDxghMRo5auSGy6A7WfXl3Nupfh/aEjmjmn:rHXq6xmMRe9SNYV3NkZr8m',
#  '6:rHKAqEDxghMRo5auSGy6A7WfXl3Nupfh/aEjmjmn:rHXq6xmMRe9SNYV3NkZr8m',
#  '6:rHKAqEDxghMRo5auSGy6A7WfXl3Nupfh/aEjmjmn:rHXq6xmMRe9SNYV3NkZr8m']

# %%
a = '6:rHKA2y6A7GyGTSjkRB9LyhvXfLTYCSUBKAQNWjyGTbzNupfh/aEjmjmn:rHX9Gy9kRB9GfLTYR+ygNkZr8m'.split(":")
":".join(a[1:])
# Out:
# 'rHKA2y6A7GyGTSjkRB9LyhvXfLTYCSUBKAQNWjyGTbzNupfh/aEjmjmn:rHX9Gy9kRB9GfLTYR+ygNkZr8m'

# %%
for i in range(1):
    print(i)
# Out:
# 0

# %%
session_payload[7]
# Out:
# ['6:rHKA2y6A7GyGTSjkRB9LyhvXfLTYCSUBKAQNWjyGTbzNupfh/aEjmjmn:rHX9Gy9kRB9GfLTYR+ygNkZr8m']

# %%
payload_li[-2][1]#[:,0]
# Out:
# array(['3:Sfrfun:Sfrmn', '1578607824.826388000'], dtype=object)

# %%
df2_http.iloc[-2,-2]#[0][0] # select in bound payload, select first packet , select hash
# Out:
# array([array(['3:cRm5tD+U/2:rHKA2', '1578607824.482844000'], dtype=object),
#        array(['3:Sfrfun:Sfrmn', '1578607824.826388000'], dtype=object)],
#       dtype=object)

# %%
ssdeep.compare(session_payload[7][0],session_payload[6][0])
# Out:
# 0
